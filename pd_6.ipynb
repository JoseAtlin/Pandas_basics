# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head(10)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 6                              I am a developer by profession       No   NaN
# 7                              I am a developer by profession      Yes   NaN
# 8                              I am a developer by profession      Yes  36.0
# 9                              I am a developer by profession       No  30.0
# 10                             I am a developer by profession      Yes  22.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
# 6                  14      NaN        NaN            NaN             Germany
# 7                  18  Monthly        NaN            NaN               India
# 8                  12   Yearly   116000.0       116000.0       United States
# 9                  20      NaN        NaN            NaN             Tunisia
# 10                 14   Yearly    25000.0        32315.0      United Kingdom
#
#                     CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                  European Euro            EUR   Microsoft SQL Server
# 2                 Pound sterling            GBP                    NaN
# 3                            NaN            NaN                    NaN
# 4                   Albanian lek            ALL                    NaN
# 5                            NaN            NaN       MySQL;PostgreSQL
# 6                  European Euro            EUR                    NaN
# 7           United States dollar            USD                    NaN
# 8           United States dollar            USD                MongoDB
# 9           United States dollar            USD                    NaN
# 10                Pound sterling            GBP   Microsoft SQL Server
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
# 6                                                 NaN
# 7                                                 NaN
# 8                                 MariaDB;MySQL;Redis
# 9                                                 NaN
# 10                               Microsoft SQL Server
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6             Designer;Developer, front-end;Developer, mobile
# 7           Developer, back-end;Developer, front-end;Devel...
# 8           Developer, back-end;Developer, desktop or ente...
# 9                                       Developer, full-stack
# 10          Database administrator;Developer, full-stack;D...
#
#                                                       EdLevel  \
# Respondent
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                         NaN
# 4             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Secondary school (e.g. American high school, G...
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9                          Professional degree (JD, MD, etc.)
# 10            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
# 6                                          Employed full-time
# 7                                          Employed full-time
# 8                                          Employed full-time
# 9           Independent contractor, freelancer, or self-em...
# 10                                         Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# 6           White or of European descent    Man
# 7                                    NaN    NaN
# 8           White or of European descent    Man
# 9                                    NaN    Man
# 10          White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
# 6           Diversity of the company or organization;Langu...
# 7                                                         NaN
# 8           Remote work options;Opportunities for professi...
# 9           Diversity of the company or organization;Remot...
# 10          Flex time or a flexible schedule;How widely us...
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# 6              Slightly satisfied
# 7                  Very satisfied
# 8           Slightly dissatisfied
# 9               Very dissatisfied
# 10                 Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
# 6                I am not interested in new job opportunities
# 7           I’m not actively looking, but I am open to new...
# 8           I’m not actively looking, but I am open to new...
# 9           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
#
#                            LanguageDesireNextYear  \
# Respondent
# 1                          C#;HTML/CSS;JavaScript
# 2                                    Python;Swift
# 3                        Objective-C;Python;Swift
# 4                                             NaN
# 5                                 Java;Ruby;Scala
# 6                        HTML/CSS;Java;JavaScript
# 7                                 C#;HTML/CSS;PHP
# 8                                      JavaScript
# 9                                     Python;Rust
# 10          HTML/CSS;Java;JavaScript;Python;R;SQL
#
#                              LanguageWorkedWith  \
# Respondent
# 1                        C#;HTML/CSS;JavaScript
# 2                              JavaScript;Swift
# 3                      Objective-C;Python;Swift
# 4                                           NaN
# 5                             HTML/CSS;Ruby;SQL
# 6                      HTML/CSS;Java;JavaScript
# 7                               C#;HTML/CSS;PHP
# 8                                    Python;SQL
# 9                       HTML/CSS;JavaScript;PHP
# 10          HTML/CSS;Java;JavaScript;Python;SQL
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# 6                                        NaN                NaN
# 7                                        NaN                NaN
# 8                                   Unity 3D            Ansible
# 9                                        NaN                NaN
# 10                         Pandas;TensorFlow             Pandas
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# 6                                     Github;Slack
# 7                                              NaN
# 8                                              NaN
# 9                                              NaN
# 10                          Github;Microsoft Teams
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# 6                              Confluence;Github;Slack;Trello  Not sure
# 7                                                         NaN       Yes
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 9           Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
# 10                                     Github;Microsoft Teams        No
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1            Somewhat important                    Fairly important
# 2                           NaN                    Fairly important
# 3                           NaN                                 NaN
# 4                           NaN  Not at all important/not necessary
# 5                           NaN                      Very important
# 6                           NaN                    Fairly important
# 7           Extremely important                      Very important
# 8           Extremely important  Not at all important/not necessary
# 9                           NaN                      Very important
# 10                      Neutral                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# 6                                                         NaN
# 7           Better compensation;Growth or leadership oppor...
# 8           Curious about other opportunities;Better compe...
# 9           Curious about other opportunities;Growth or le...
# 10          Curious about other opportunities;Better compe...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# 6                                                         NaN
# 7           Read company media, such as employee blogs or ...
# 8           Read company media, such as employee blogs or ...
# 9                                                         NaN
# 10          Company reviews from third party sites (e.g. G...
#
#                     NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 1                Once a year    Not sure                           NaN
# 2                Once a year    Not sure                           NaN
# 3              Once a decade         NaN                           NaN
# 4                Once a year    Not sure                           Yes
# 5                Once a year          No                           NaN
# 6                Once a year          No                            No
# 7           Every few months         Yes                           Yes
# 8                Once a year    Not sure                           Yes
# 9                Once a year          No                           Yes
# 10          Every few months         Yes  Onboarding? What onboarding?
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 1                     No                   Often: 1-2 days per week or more
# 2                     No                                                NaN
# 3                     No                                                NaN
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 5                    Yes                                                NaN
# 6                     No                                              Never
# 7                     No  Sometimes: 1-2 days per month but less than we...
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 9                     No  Occasionally: 1-2 days per quarter but less th...
# 10                    No                   Often: 1-2 days per week or more
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# 6           Ask developers I know/work with;Read ratings o...
# 7           Start a free trial;Ask developers I know/work ...
# 8           Start a free trial;Ask developers I know/work ...
# 9                                          Start a free trial
# 10          Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# 6                      Amused
# 7                         NaN
# 8           Hello, old friend
# 9           Hello, old friend
# 10          Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# 6           Stack Overflow (public Q&A for anyone who code...
# 7            Stack Overflow (public Q&A for anyone who codes)
# 8           Stack Overflow (public Q&A for anyone who code...
# 9           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# 6           Play games;Visit Stack Overflow;Watch help / t...      Windows
# 7                                                         NaN      Windows
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 9                                                    Meditate      Windows
# 10                                       Visit Stack Overflow      Windows
#
#                                                       OrgSize  \
# Respondent
# 1                                            2 to 9 employees
# 2                                    1,000 to 4,999 employees
# 3                                                         NaN
# 4                                          20 to 99 employees
# 5                                                         NaN
# 6                                                         NaN
# 7                                          20 to 99 employees
# 8                                          20 to 99 employees
# 9           Just me - I am a freelancer, sole proprietor, ...
# 10                                           2 to 9 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# 6                                                     Android
# 7                                                         NaN
# 8                             iOS;Slack Apps and Integrations
# 9                                                         NaN
# 10                         Android;Linux;Raspberry Pi;Windows
#
#                             PlatformWorkedWith  \
# Respondent
# 1                                      Windows
# 2                                          iOS
# 3                                          NaN
# 4                                          NaN
# 5               AWS;Docker;Linux;MacOS;Windows
# 6                     Android;Docker;WordPress
# 7                                          NaN
# 8                                       Docker
# 9                                    WordPress
# 10          Android;Linux;Raspberry Pi;Windows
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# 6                      I have some influence  Straight / Heterosexual
# 7                                        NaN                      NaN
# 8                      I have some influence  Straight / Heterosexual
# 9                                        NaN  Straight / Heterosexual
# 10          I have a great deal of influence  Straight / Heterosexual
#
#            SOAccount           SOComm                           SOPartFreq  \
# Respondent
# 1                 No   No, not at all                                  NaN
# 2                Yes  Yes, definitely  Less than once per month or monthly
# 3                Yes    Yes, somewhat      A few times per month or weekly
# 4                Yes  Yes, definitely      A few times per month or weekly
# 5                Yes    Yes, somewhat  Less than once per month or monthly
# 6                Yes    Yes, somewhat      A few times per month or weekly
# 7                Yes  Yes, definitely               Multiple times per day
# 8                Yes   No, not really  Less than once per month or monthly
# 9                Yes  Yes, definitely               Multiple times per day
# 10               Yes  Yes, definitely               Multiple times per day
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# 6                      A few times per week  Neither easy nor difficult
# 7                    Multiple times per day                         NaN
# 8                    Multiple times per day                        Easy
# 9                    Multiple times per day  Neither easy nor difficult
# 10                   Multiple times per day                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# 6           Appropriate in length   NaN
# 7                             NaN   NaN
# 8           Appropriate in length    No
# 9           Appropriate in length    No
# 10          Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# 6                                                         NaN
# 7           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                  Mathematics or statistics
#
#             WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                     ASP.NET Core  ASP.NET;ASP.NET Core
# 2                              NaN                   NaN
# 3                              NaN                   NaN
# 4                              NaN                   NaN
# 5             Django;Ruby on Rails         Ruby on Rails
# 6                         React.js                   NaN
# 7                              NaN                   NaN
# 8           Django;React.js;Vue.js                 Flask
# 9                       Angular.js                jQuery
# 10                    Flask;jQuery          Flask;jQuery
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# 6                                                NaN          NaN         6
# 7              A lot more welcome now than last year          NaN         6
# 8            Just as welcome now as I felt last year         39.0        17
# 9            Just as welcome now as I felt last year         50.0         6
# 10          Somewhat more welcome now than last year         36.0         8
#
#            YearsCodePro
# Respondent
# 1                    27
# 2                     4
# 3                   NaN
# 4                     4
# 5                     8
# 6                     4
# 7                     4
# 8                    13
# 9                     4
# 10                    4

# %%
df.sort_values(by='Age1stCode', inplace=True)
df.head(10)
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 32694       I am a student who is learning to code      Yes  19.0         10
# 54173               I am a developer by profession       No  25.0         10
# 25483               I am a developer by profession      Yes  22.0         10
# 2696                I am a developer by profession       No   NaN         10
# 54169               I am a developer by profession      Yes  25.0         10
# 20110       I am a student who is learning to code      Yes  14.0         10
# 7343                I am a developer by profession      Yes   NaN         10
# 12125               I am a developer by profession      Yes  53.0         10
# 54149               I am a developer by profession      Yes  21.0         10
# 20119               I am a developer by profession      Yes   NaN         10
#
#            CompFreq  CompTotal  ConvertedComp         Country  \
# Respondent
# 32694           NaN        NaN            NaN   United States
# 54173        Yearly    80200.0        80200.0   United States
# 25483           NaN        NaN            NaN          Israel
# 2696         Yearly   100000.0       100000.0   United States
# 54169        Yearly    65000.0        43426.0       Australia
# 20110           NaN        NaN            NaN       Australia
# 7343        Monthly    32000.0        55572.0         Denmark
# 12125        Yearly    60000.0        77556.0  United Kingdom
# 54149        Yearly    70400.0        70400.0   United States
# 20119        Weekly        NaN            NaN   United States
#
#                     CurrencyDesc CurrencySymbol  \
# Respondent
# 32694                        NaN            NaN
# 54173       United States dollar            USD
# 25483         Israeli new shekel            ILS
# 2696        United States dollar            USD
# 54169          Australian dollar            AUD
# 20110                        NaN            NaN
# 7343                Danish krone            DKK
# 12125             Pound sterling            GBP
# 54149       United States dollar            USD
# 20119       United States dollar            USD
#
#                             DatabaseDesireNextYear  \
# Respondent
# 32694                      MySQL;PostgreSQL;SQLite
# 54173                             MySQL;PostgreSQL
# 25483                Firebase;Microsoft SQL Server
# 2696                                           NaN
# 54169                        Elasticsearch;MongoDB
# 20110       Elasticsearch;MongoDB;MySQL;PostgreSQL
# 7343          Elasticsearch;Firebase;MongoDB;Redis
# 12125                                          NaN
# 54149              DynamoDB;MySQL;PostgreSQL;Redis
# 20119       Microsoft SQL Server;PostgreSQL;SQLite
#
#                                            DatabaseWorkedWith  \
# Respondent
# 32694            Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 54173                                        MySQL;PostgreSQL
# 25483                                          MongoDB;SQLite
# 2696                                                    MySQL
# 54169                                  Elasticsearch;Firebase
# 20110                  Elasticsearch;MongoDB;MySQL;PostgreSQL
# 7343               Elasticsearch;Firebase;MongoDB;MySQL;Redis
# 12125                                                     NaN
# 54149                               DynamoDB;MySQL;PostgreSQL
# 20119       Elasticsearch;Microsoft SQL Server;PostgreSQL;...
#
#                                                       DevType  \
# Respondent
# 32694                                                     NaN
# 54173       Developer, back-end;Developer, front-end;Devel...
# 25483       Developer, back-end;Developer, front-end;Devel...
# 2696                Developer, back-end;Developer, full-stack
# 54169                                   Developer, full-stack
# 20110                                                     NaN
# 7343        Developer, back-end;Developer, front-end;Devel...
# 12125       Designer;Developer, back-end;Developer, deskto...
# 54149       Database administrator;Developer, back-end;Dev...
# 20119       Developer, back-end;Developer, front-end;Devel...
#
#                                                       EdLevel  \
# Respondent
# 32694       Secondary school (e.g. American high school, G...
# 54173            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 25483            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2696             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54169            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 20110       Secondary school (e.g. American high school, G...
# 7343             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12125            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 54149       Secondary school (e.g. American high school, G...
# 20119            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                     Employment  \
# Respondent
# 32694                  Student
# 54173       Employed full-time
# 25483       Employed full-time
# 2696        Employed full-time
# 54169       Employed full-time
# 20110                  Student
# 7343        Employed full-time
# 12125       Employed full-time
# 54149       Employed full-time
# 20119       Employed full-time
#
#                                                     Ethnicity  \
# Respondent
# 32694       White or of European descent;Biracial;South Asian
# 54173       Hispanic or Latino/a/x;White or of European de...
# 25483                                                     NaN
# 2696        White or of European descent;Biracial;Indigeno...
# 54169                            White or of European descent
# 20110                            White or of European descent
# 7343                             White or of European descent
# 12125                            White or of European descent
# 54149                            White or of European descent
# 20119                            White or of European descent
#
#                                                        Gender  \
# Respondent
# 32694                                                     Man
# 54173       Woman;Non-binary, genderqueer, or gender non-c...
# 25483                                                     Man
# 2696                                                    Woman
# 54169                                                     Man
# 20110                                                     Man
# 7343                                                      Man
# 12125                                                     Man
# 54149                                                     Man
# 20119                                                     Man
#
#                                                    JobFactors  \
# Respondent
# 32694       Industry that I’d be working in;Languages, fra...
# 54173       Diversity of the company or organization;Flex ...
# 25483       Industry that I’d be working in;How widely use...
# 2696        Flex time or a flexible schedule;Office enviro...
# 54169       Flex time or a flexible schedule;Remote work o...
# 20110       Flex time or a flexible schedule;Financial per...
# 7343        Industry that I’d be working in;Languages, fra...
# 12125       Flex time or a flexible schedule;Remote work o...
# 54149       Languages, frameworks, and other technologies ...
# 20119       Industry that I’d be working in;Diversity of t...
#
#                            JobSat  \
# Respondent
# 32694                         NaN
# 54173              Very satisfied
# 25483          Slightly satisfied
# 2696               Very satisfied
# 54169          Slightly satisfied
# 20110                         NaN
# 7343               Very satisfied
# 12125       Slightly dissatisfied
# 54149       Slightly dissatisfied
# 20119          Slightly satisfied
#
#                                                       JobSeek  \
# Respondent
# 32694       I’m not actively looking, but I am open to new...
# 54173       I’m not actively looking, but I am open to new...
# 25483            I am not interested in new job opportunities
# 2696             I am not interested in new job opportunities
# 54169       I’m not actively looking, but I am open to new...
# 20110            I am not interested in new job opportunities
# 7343             I am not interested in new job opportunities
# 12125       I’m not actively looking, but I am open to new...
# 54149       I’m not actively looking, but I am open to new...
# 20119            I am not interested in new job opportunities
#
#                                        LanguageDesireNextYear  \
# Respondent
# 32694                                      C;Python;SQL;Swift
# 54173                                       Go;Rust;Scala;SQL
# 25483       C#;Go;HTML/CSS;JavaScript;Kotlin;Python;TypeSc...
# 2696                                                      NaN
# 54169                                                 C#;Rust
# 20110       Bash/Shell/PowerShell;C;C#;C++;Haskell;HTML/CS...
# 7343                                          Go;Python;Swift
# 12125                                              C++;Python
# 54149       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;P...
# 20119       C#;Dart;Java;JavaScript;Kotlin;Objective-C;SQL...
#
#                                            LanguageWorkedWith  \
# Respondent
# 32694                                       C;Java;Python;SQL
# 54173       Bash/Shell/PowerShell;Go;HTML/CSS;JavaScript;S...
# 25483                             C#;HTML/CSS;Java;JavaScript
# 2696        Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;SQL
# 54169             Bash/Shell/PowerShell;JavaScript;PHP;Python
# 20110       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 7343                       HTML/CSS;JavaScript;SQL;TypeScript
# 12125                                                C;C#;C++
# 54149       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 20119       Bash/Shell/PowerShell;C#;C++;HTML/CSS;Java;Jav...
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 32694                                                 Ansible
# 54173                                                 Node.js
# 25483       .NET;.NET Core;Apache Spark;Hadoop;Keras;Node....
# 2696                                                 Unity 3D
# 54169                                                Unity 3D
# 20110                                                 Node.js
# 7343                            Node.js;React Native;Teraform
# 12125                                  Unity 3D;Unreal Engine
# 54149                                                 Node.js
# 20119                                         Node.js;Xamarin
#
#                        MiscTechWorkedWith  \
# Respondent
# 32694                             Ansible
# 54173                             Node.js
# 25483                        .NET;Node.js
# 2696                              Node.js
# 54169                              Pandas
# 20110                             Node.js
# 7343        Node.js;React Native;Teraform
# 12125                      .NET;.NET Core
# 54149                             Node.js
# 20119                     Node.js;Xamarin
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 32694       Github;Microsoft Teams;Google Suite (Docs, Mee...
# 54173                            Confluence;Jira;Github;Slack
# 25483              Confluence;Jira;Github;Gitlab;Slack;Trello
# 2696                   Confluence;Jira;Github;Microsoft Azure
# 54169                                                  Github
# 20110       Github;Slack;Google Suite (Docs, Meet, etc);St...
# 7343                            Confluence;Jira;Github;Trello
# 12125            Github;Gitlab;Google Suite (Docs, Meet, etc)
# 54149       Jira;Github;Gitlab;Slack;Google Suite (Docs, M...
# 20119                            Github;Slack;Microsoft Azure
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 32694       Github;Microsoft Teams;Google Suite (Docs, Mee...       NaN
# 54173       Github;Slack;Trello;Google Suite (Docs, Meet, ...        No
# 25483                                                  Github       Yes
# 2696        Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 54169                                       Jira;Github;Slack       Yes
# 20110       Github;Slack;Google Suite (Docs, Meet, etc);St...       NaN
# 7343                            Confluence;Jira;Github;Trello       Yes
# 12125            Github;Gitlab;Google Suite (Docs, Meet, etc)        No
# 54149             Github;Slack;Google Suite (Docs, Meet, etc)       Yes
# 20119       Confluence;Jira;Github;Slack;Microsoft Azure;T...       Yes
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 32694                       NaN                                 NaN
# 54173       Extremely important                    Fairly important
# 25483        Somewhat important                      Very important
# 2696        Extremely important                  Somewhat important
# 54169       Extremely important                      Very important
# 20110                       NaN                                 NaN
# 7343         Somewhat important  Not at all important/not necessary
# 12125        Somewhat important  Not at all important/not necessary
# 54149       Extremely important  Not at all important/not necessary
# 20119       Extremely important                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 32694                                                     NaN
# 54173       Just because;Having a bad day (or week or mont...
# 25483       Just because;Curious about other opportunities...
# 2696        Curious about other opportunities;Better compe...
# 54169       Trouble with my direct manager;Trouble with le...
# 20110                                                     NaN
# 7343        Curious about other opportunities;Better compe...
# 12125       Better work/life balance;Wanting to work with ...
# 54149       Having a bad day (or week or month) at work;Cu...
# 20119       Better compensation;Trouble with my direct man...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 32694                                                     NaN
# 54173       Read company media, such as employee blogs or ...
# 25483       Company reviews from third party sites (e.g. G...
# 2696        Read company media, such as employee blogs or ...
# 54169       Read company media, such as employee blogs or ...
# 20110                                                     NaN
# 7343        Read company media, such as employee blogs or ...
# 12125       Company reviews from third party sites (e.g. G...
# 54149       Read company media, such as employee blogs or ...
# 20119       Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 32694           Every few months         Yes                           NaN
# 54173           Every few months         Yes                            No
# 25483           Every few months          No                           Yes
# 2696        Once every few years    Not sure                           Yes
# 54169                Once a year    Not sure                           Yes
# 20110           Every few months         Yes                           NaN
# 7343                 Once a year    Not sure                           Yes
# 12125           Every few months    Not sure                           Yes
# 54149                Once a year    Not sure  Onboarding? What onboarding?
# 20119           Every few months          No                            No
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 32694                 No                                                NaN
# 54173                Yes  Sometimes: 1-2 days per month but less than we...
# 25483                 No                   Often: 1-2 days per week or more
# 2696                  No  Occasionally: 1-2 days per quarter but less th...
# 54169                 No  Sometimes: 1-2 days per month but less than we...
# 20110                 No                                                NaN
# 7343                  No  Occasionally: 1-2 days per quarter but less th...
# 12125                Yes                  Rarely: 1-2 days per year or less
# 54149                Yes                  Rarely: 1-2 days per year or less
# 20119                Yes  Occasionally: 1-2 days per quarter but less th...
#
#                                           NEWPurchaseResearch  \
# Respondent
# 32694       Start a free trial;Visit developer communities...
# 54173       Start a free trial;Ask developers I know/work ...
# 25483                                                     NaN
# 2696        Start a free trial;Ask developers I know/work ...
# 54169       Start a free trial;Visit developer communities...
# 20110       Start a free trial;Ask developers I know/work ...
# 7343        Start a free trial;Ask developers I know/work ...
# 12125       Start a free trial;Ask developers I know/work ...
# 54149                                                     NaN
# 20119       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 32694       Hello, old friend
# 54173                  Amused
# 25483                 Annoyed
# 2696        Hello, old friend
# 54169                  Amused
# 20110             Indifferent
# 7343        Hello, old friend
# 12125             Indifferent
# 54149                 Annoyed
# 20119       Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 32694       Stack Overflow (public Q&A for anyone who code...
# 54173       Stack Overflow (public Q&A for anyone who code...
# 25483       Stack Overflow (public Q&A for anyone who code...
# 2696        Stack Overflow (public Q&A for anyone who code...
# 54169       Stack Overflow (public Q&A for anyone who code...
# 20110       Stack Overflow (public Q&A for anyone who code...
# 7343        Stack Overflow (public Q&A for anyone who code...
# 12125       Stack Overflow (public Q&A for anyone who code...
# 54149       Stack Overflow (public Q&A for anyone who code...
# 20119       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 32694                     Meditate;Visit Stack Overflow;Panic      Windows
# 54173       Call a coworker or friend;Visit Stack Overflow...        MacOS
# 25483       Call a coworker or friend;Visit Stack Overflow...      Windows
# 2696        Visit Stack Overflow;Go for a walk or other ph...  Linux-based
# 54169       Visit Stack Overflow;Watch help / tutorial vid...  Linux-based
# 20110       Visit Stack Overflow;Watch help / tutorial vid...        MacOS
# 7343        Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 12125       Visit Stack Overflow;Do other work and come ba...      Windows
# 54149       Call a coworker or friend;Visit Stack Overflow...        MacOS
# 20119       Visit Stack Overflow;Go for a walk or other ph...        MacOS
#
#                              OrgSize  \
# Respondent
# 32694                            NaN
# 54173             20 to 99 employees
# 25483       10,000 or more employees
# 2696            100 to 499 employees
# 54169             10 to 19 employees
# 20110                            NaN
# 7343              20 to 99 employees
# 12125               2 to 9 employees
# 54149             10 to 19 employees
# 20119             20 to 99 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 32694                     Kubernetes;Linux;MacOS;Raspberry Pi
# 54173                 Docker;Google Cloud Platform;Kubernetes
# 25483       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 2696                  Docker;Kubernetes;Linux;Microsoft Azure
# 54169                               AWS;Google Cloud Platform
# 20110       AWS;iOS;Linux;MacOS;Raspberry Pi;Slack Apps an...
# 7343        Docker;Google Cloud Platform;iOS;Kubernetes;MacOS
# 12125                                   Android;Linux;Windows
# 54149                       AWS;Docker;Kubernetes;Linux;MacOS
# 20119            Android;AWS;Docker;iOS;MacOS;Microsoft Azure
#
#                                            PlatformWorkedWith  \
# Respondent
# 32694                              Linux;Raspberry Pi;Windows
# 54173       Docker;Google Cloud Platform;Kubernetes;Slack ...
# 25483                                                 Windows
# 2696                                         AWS;Docker;Linux
# 54169                                   Google Cloud Platform
# 20110       AWS;iOS;Linux;MacOS;Raspberry Pi;Slack Apps an...
# 7343                      Docker;Google Cloud Platform;Heroku
# 12125                                           Linux;Windows
# 54149                                  AWS;Docker;Linux;MacOS
# 20119       Android;AWS;Docker;Google Cloud Platform;iOS;L...
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 32694                                    NaN  Straight / Heterosexual
# 54173                  I have some influence           Bisexual;Queer
# 25483          I have little or no influence  Straight / Heterosexual
# 2696                   I have some influence           Bisexual;Queer
# 54169                  I have some influence                 Bisexual
# 20110                                    NaN  Straight / Heterosexual
# 7343        I have a great deal of influence  Straight / Heterosexual
# 12125                  I have some influence  Straight / Heterosexual
# 54149          I have little or no influence  Straight / Heterosexual
# 20119                  I have some influence  Straight / Heterosexual
#
#            SOAccount           SOComm  \
# Respondent
# 32694             No   No, not at all
# 54173             No   No, not at all
# 25483            Yes  Yes, definitely
# 2696             Yes   No, not really
# 54169            Yes   No, not really
# 20110            Yes  Yes, definitely
# 7343             Yes   No, not really
# 12125            Yes          Neutral
# 54149            Yes   No, not really
# 20119            Yes    Yes, somewhat
#
#                                                    SOPartFreq  \
# Respondent
# 32694                                                     NaN
# 54173                                                     NaN
# 25483                                    A few times per week
# 2696                      Less than once per month or monthly
# 54169       I have never participated in Q&A on Stack Over...
# 20110                                   Daily or almost daily
# 7343        I have never participated in Q&A on Stack Over...
# 12125                                    A few times per week
# 54149                     Less than once per month or monthly
# 20119                                    A few times per week
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 32694                 Daily or almost daily                        Easy
# 54173       A few times per month or weekly                        Easy
# 25483                 Daily or almost daily                        Easy
# 2696                 Multiple times per day                        Easy
# 54169                Multiple times per day                        Easy
# 20110                Multiple times per day  Neither easy nor difficult
# 7343                  Daily or almost daily                        Easy
# 12125                 Daily or almost daily                        Easy
# 54149                 Daily or almost daily                        Easy
# 20119                Multiple times per day  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# 32694       Appropriate in length    No
# 54173       Appropriate in length   NaN
# 25483                    Too long    No
# 2696        Appropriate in length    No
# 54169       Appropriate in length    No
# 20110       Appropriate in length    No
# 7343        Appropriate in length    No
# 12125       Appropriate in length    No
# 54149       Appropriate in length    No
# 20119       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 32694                                                     NaN
# 54173       A social science (such as anthropology, psycho...
# 25483       Computer science, computer engineering, or sof...
# 2696                                Mathematics or statistics
# 54169       Information systems, information technology, o...
# 20110                                                     NaN
# 7343        A health science (such as nursing, pharmacy, r...
# 12125       Computer science, computer engineering, or sof...
# 54149                                                     NaN
# 20119       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 32694                                            Django;Flask
# 54173                                                  Gatsby
# 25483       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 2696                                                   jQuery
# 54169                               Angular.js;Express;Vue.js
# 20110           Angular.js;Django;Express;Flask;jQuery;Vue.js
# 7343                                         Express;React.js
# 12125                                                     NaN
# 54149                    Django;Express;Flask;React.js;Vue.js
# 20119                                         Angular;Express
#
#                           WebframeWorkedWith  \
# Respondent
# 32694                           Django;Flask
# 54173                Express;Gatsby;React.js
# 25483       Angular.js;ASP.NET;Express;Flask
# 2696                                  jQuery
# 54169                    Flask;jQuery;Vue.js
# 20110            Express;Flask;jQuery;Vue.js
# 7343                        Express;React.js
# 12125                                    NaN
# 54149                   Express;Flask;Vue.js
# 20119                        Angular;Express
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 32694        Just as welcome now as I felt last year          NaN         6
# 54173       Somewhat more welcome now than last year         40.0         3
# 25483       Somewhat more welcome now than last year         45.0         4
# 2696         Just as welcome now as I felt last year         40.0        38
# 54169          A lot more welcome now than last year         40.0         9
# 20110        Just as welcome now as I felt last year          NaN         5
# 7343         Just as welcome now as I felt last year         37.0         3
# 12125       Somewhat less welcome now than last year         38.0        43
# 54149        Just as welcome now as I felt last year         35.0        11
# 20119        Just as welcome now as I felt last year         40.0        38
#
#                 YearsCodePro
# Respondent
# 32694                    NaN
# 54173                      3
# 25483       Less than 1 year
# 2696                      23
# 54169                      3
# 20110                    NaN
# 7343                       2
# 12125                     32
# 54149                      6
# 20119                     20

# %%
df.sort_index()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 65634                          I am a developer by profession      Yes   NaN
# 65635                          I am a developer by profession      Yes   NaN
# 65636                          I am a developer by profession      Yes   NaN
# 65637                  I am a student who is learning to code      Yes   NaN
# 65639                  I am a student who is learning to code       No   NaN
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
# ...               ...      ...        ...            ...                 ...
# 65634             NaN      NaN        NaN            NaN         Philippines
# 65635              15      NaN        NaN            NaN         Philippines
# 65636             NaN      NaN        NaN            NaN           Argentina
# 65637             NaN      NaN        NaN            NaN            Ethiopia
# 65639             NaN      NaN        NaN            NaN             Georgia
#
#               CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1            European Euro            EUR   Microsoft SQL Server
# 2           Pound sterling            GBP                    NaN
# 3                      NaN            NaN                    NaN
# 4             Albanian lek            ALL                    NaN
# 5                      NaN            NaN       MySQL;PostgreSQL
# ...                    ...            ...                    ...
# 65634                  NaN            NaN          Oracle;SQLite
# 65635                  NaN            NaN                    NaN
# 65636                  NaN            NaN                    NaN
# 65637                  NaN            NaN                    NaN
# 65639                  NaN            NaN                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                       MySQL;PostgreSQL;Redis;SQLite
# ...                                               ...
# 65634                                   Oracle;SQLite
# 65635                                             NaN
# 65636                                             NaN
# 65637                                             NaN
# 65639                                             NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
# ...                                                       ...
# 65634                                                     NaN
# 65635       Developer, back-end;Developer, desktop or ente...
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                     ...
# 65634                                                   NaN
# 65635          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65636                                                   NaN
# 65637                                                   NaN
# 65639                                                   NaN
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
# ...                                                       ...
# 65634                                      Employed full-time
# 65635                                      Employed full-time
# 65636                                      Employed full-time
# 65637                                                 Student
# 65639                                                 Student
#
#                                Ethnicity Gender  \
# Respondent
# 1           White or of European descent    Man
# 2                                    NaN    NaN
# 3                                    NaN    NaN
# 4           White or of European descent    Man
# 5           White or of European descent    Man
# ...                                  ...    ...
# 65634                                NaN    NaN
# 65635                                NaN    NaN
# 65636                                NaN    NaN
# 65637                                NaN    NaN
# 65639                                NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 2                                                         NaN
# 3                                                         NaN
# 4           Flex time or a flexible schedule;Office enviro...
# 5                                                         NaN
# ...                                                       ...
# 65634                                                     NaN
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                            JobSat  \
# Respondent
# 1              Slightly satisfied
# 2               Very dissatisfied
# 3                             NaN
# 4           Slightly dissatisfied
# 5                             NaN
# ...                           ...
# 65634                         NaN
# 65635                         NaN
# 65636                         NaN
# 65637                         NaN
# 65639                         NaN
#
#                                                       JobSeek  \
# Respondent
# 1                I am not interested in new job opportunities
# 2                I am not interested in new job opportunities
# 3                                                         NaN
# 4           I’m not actively looking, but I am open to new...
# 5                                                         NaN
# ...                                                       ...
# 65634                                                     NaN
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#               LanguageDesireNextYear        LanguageWorkedWith  \
# Respondent
# 1             C#;HTML/CSS;JavaScript    C#;HTML/CSS;JavaScript
# 2                       Python;Swift          JavaScript;Swift
# 3           Objective-C;Python;Swift  Objective-C;Python;Swift
# 4                                NaN                       NaN
# 5                    Java;Ruby;Scala         HTML/CSS;Ruby;SQL
# ...                              ...                       ...
# 65634       HTML/CSS;Java;JavaScript  HTML/CSS;Java;JavaScript
# 65635                            NaN                       NaN
# 65636                            NaN                       NaN
# 65637                            NaN                       NaN
# 65639                            NaN                       NaN
#
#                       MiscTechDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                          .NET Core;Xamarin     .NET;.NET Core
# 2           React Native;TensorFlow;Unity 3D       React Native
# 3                                        NaN                NaN
# 4                                        NaN                NaN
# 5                               Ansible;Chef            Ansible
# ...                                      ...                ...
# 65634                                    NaN                NaN
# 65635                                    NaN                NaN
# 65636                                    NaN                NaN
# 65637                                    NaN                NaN
# 65639                                    NaN                NaN
#
#                       NEWCollabToolsDesireNextYear  \
# Respondent
# 1           Microsoft Teams;Microsoft Azure;Trello
# 2                                     Github;Slack
# 3                                              NaN
# 4                                              NaN
# 5            Github;Google Suite (Docs, Meet, etc)
# ...                                            ...
# 65634                                        Slack
# 65635                                          NaN
# 65636                                          NaN
# 65637                                          NaN
# 65639                                          NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 1                Confluence;Jira;Slack;Microsoft Azure;Trello        No
# 2                         Confluence;Jira;Github;Gitlab;Slack       NaN
# 3                                                         NaN       NaN
# 4                                                         NaN        No
# 5           Confluence;Jira;Github;Slack;Google Suite (Doc...       NaN
# ...                                                       ...       ...
# 65634                                                   Slack       NaN
# 65635                                                     NaN       NaN
# 65636                                                     NaN       NaN
# 65637                                                     NaN       NaN
# 65639                                                     NaN       NaN
#
#                  NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 1           Somewhat important                    Fairly important
# 2                          NaN                    Fairly important
# 3                          NaN                                 NaN
# 4                          NaN  Not at all important/not necessary
# 5                          NaN                      Very important
# ...                        ...                                 ...
# 65634                      NaN                                 NaN
# 65635                      NaN                      Very important
# 65636                      NaN                                 NaN
# 65637                      NaN                                 NaN
# 65639                      NaN                                 NaN
#
#                                                    NEWJobHunt  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                         NaN
# 4           Curious about other opportunities;Wanting to w...
# 5                                                         NaN
# ...                                                       ...
# 65634                                                     NaN
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#            NEWJobHuntResearch              NEWLearn NEWOffTopic  \
# Respondent
# 1                         NaN           Once a year    Not sure
# 2                         NaN           Once a year    Not sure
# 3                         NaN         Once a decade         NaN
# 4                         NaN           Once a year    Not sure
# 5                         NaN           Once a year          No
# ...                       ...                   ...         ...
# 65634                     NaN                   NaN         NaN
# 65635                     NaN                   NaN         NaN
# 65636                     NaN           Once a year         NaN
# 65637                     NaN                   NaN         NaN
# 65639                     NaN  Once every few years         NaN
#
#            NEWOnboardGood NEWOtherComms  \
# Respondent
# 1                     NaN            No
# 2                     NaN            No
# 3                     NaN            No
# 4                     Yes           Yes
# 5                     NaN           Yes
# ...                   ...           ...
# 65634                 NaN           Yes
# 65635                 NaN           NaN
# 65636                 NaN           NaN
# 65637                 NaN           NaN
# 65639                 NaN           NaN
#
#                                                   NEWOvertime  \
# Respondent
# 1                            Often: 1-2 days per week or more
# 2                                                         NaN
# 3                                                         NaN
# 4           Occasionally: 1-2 days per quarter but less th...
# 5                                                         NaN
# ...                                                       ...
# 65634                                                     NaN
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 1           Start a free trial;Ask developers I know/work ...
# 2                                                         NaN
# 3                                                         NaN
# 4                                                         NaN
# 5           Start a free trial;Ask developers I know/work ...
# ...                                                       ...
# 65634                                                     NaN
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 1                      Amused
# 2                      Amused
# 3                         NaN
# 4                         NaN
# 5           Hello, old friend
# ...                       ...
# 65634                  Amused
# 65635                     NaN
# 65636                     NaN
# 65637                     NaN
# 65639                 Annoyed
#
#                                                    NEWSOSites  \
# Respondent
# 1            Stack Overflow (public Q&A for anyone who codes)
# 2           Stack Overflow (public Q&A for anyone who code...
# 3            Stack Overflow (public Q&A for anyone who codes)
# 4           Stack Overflow (public Q&A for anyone who code...
# 5           Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 65634        Stack Overflow (public Q&A for anyone who codes)
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
# ...                                                       ...          ...
# 65634       Meditate;Visit Stack Overflow;Watch help / tut...      Windows
# 65635                                                     NaN          NaN
# 65636                                                     NaN          NaN
# 65637                                                     NaN          NaN
# 65639                       Do other work and come back later          NaN
#
#                              OrgSize  \
# Respondent
# 1                   2 to 9 employees
# 2           1,000 to 4,999 employees
# 3                                NaN
# 4                 20 to 99 employees
# 5                                NaN
# ...                              ...
# 65634                            NaN
# 65635                            NaN
# 65636                            NaN
# 65637                            NaN
# 65639                            NaN
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
# ...                                                       ...
# 65634                 Android;Arduino;Linux;Windows;WordPress
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                                  PlatformWorkedWith  \
# Respondent
# 1                                           Windows
# 2                                               iOS
# 3                                               NaN
# 4                                               NaN
# 5                    AWS;Docker;Linux;MacOS;Windows
# ...                                             ...
# 65634       Android;Arduino;Linux;Windows;WordPress
# 65635                                           NaN
# 65636                                           NaN
# 65637                                           NaN
# 65639                                           NaN
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 1                                        NaN  Straight / Heterosexual
# 2              I have little or no influence                      NaN
# 3                                        NaN                      NaN
# 4           I have a great deal of influence  Straight / Heterosexual
# 5                                        NaN  Straight / Heterosexual
# ...                                      ...                      ...
# 65634          I have little or no influence                      NaN
# 65635                                    NaN                      NaN
# 65636                                    NaN                      NaN
# 65637                                    NaN                      NaN
# 65639                                    NaN                      NaN
#
#            SOAccount           SOComm  \
# Respondent
# 1                 No   No, not at all
# 2                Yes  Yes, definitely
# 3                Yes    Yes, somewhat
# 4                Yes  Yes, definitely
# 5                Yes    Yes, somewhat
# ...              ...              ...
# 65634            Yes          Neutral
# 65635            NaN              NaN
# 65636            NaN              NaN
# 65637            NaN              NaN
# 65639            NaN              NaN
#
#                                                    SOPartFreq  \
# Respondent
# 1                                                         NaN
# 2                         Less than once per month or monthly
# 3                             A few times per month or weekly
# 4                             A few times per month or weekly
# 5                         Less than once per month or monthly
# ...                                                       ...
# 65634       I have never participated in Q&A on Stack Over...
# 65635                                                     NaN
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 1                    Multiple times per day  Neither easy nor difficult
# 2                    Multiple times per day                         NaN
# 3                     Daily or almost daily  Neither easy nor difficult
# 4                    Multiple times per day                         NaN
# 5           A few times per month or weekly                        Easy
# ...                                     ...                         ...
# 65634                Multiple times per day                         NaN
# 65635                                   NaN                         NaN
# 65636                                   NaN                         NaN
# 65637                                   NaN                         NaN
# 65639                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 1           Appropriate in length    No
# 2                             NaN   NaN
# 3           Appropriate in length   NaN
# 4                             NaN    No
# 5                       Too short    No
# ...                           ...   ...
# 65634                         NaN   NaN
# 65635                         NaN   NaN
# 65636                         NaN   NaN
# 65637                         NaN   NaN
# 65639                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 1           Computer science, computer engineering, or sof...
# 2           Computer science, computer engineering, or sof...
# 3                                                         NaN
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 65634                                                     NaN
# 65635       Information systems, information technology, o...
# 65636                                                     NaN
# 65637                                                     NaN
# 65639                                                     NaN
#
#            WebframeDesireNextYear    WebframeWorkedWith  \
# Respondent
# 1                    ASP.NET Core  ASP.NET;ASP.NET Core
# 2                             NaN                   NaN
# 3                             NaN                   NaN
# 4                             NaN                   NaN
# 5            Django;Ruby on Rails         Ruby on Rails
# ...                           ...                   ...
# 65634                    React.js              React.js
# 65635                         NaN                   NaN
# 65636                         NaN                   NaN
# 65637                         NaN                   NaN
# 65639                         NaN                   NaN
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 1            Just as welcome now as I felt last year         50.0        36
# 2           Somewhat more welcome now than last year          NaN         7
# 3           Somewhat more welcome now than last year          NaN         4
# 4           Somewhat less welcome now than last year         40.0         7
# 5            Just as welcome now as I felt last year          NaN        15
# ...                                              ...          ...       ...
# 65634                                            NaN          NaN       NaN
# 65635                                            NaN          NaN         6
# 65636                                            NaN          NaN       NaN
# 65637                                            NaN          NaN       NaN
# 65639                                            NaN          NaN       NaN
#
#                 YearsCodePro
# Respondent
# 1                         27
# 2                          4
# 3                        NaN
# 4                          4
# 5                          8
# ...                      ...
# 65634                    NaN
# 65635       Less than 1 year
# 65636                    NaN
# 65637                    NaN
# 65639                    NaN
#
# [64461 rows x 60 columns]

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)
df.head(25)
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 65381                          I am a developer by profession       No   NaN
# 65456                          I am a developer by profession      Yes   NaN
# 62788                          I am a developer by profession      Yes   NaN
# 38672                          I am a developer by profession       No   NaN
# 28374                          I am a developer by profession      Yes   NaN
# 63848                          I am a developer by profession      Yes   NaN
# 9839        I am not primarily a developer, but I write co...       No  30.0
# 51862                          I am a developer by profession      Yes  15.0
# 51509                          I am a developer by profession       No  28.0
# 44484                          I am a developer by profession      Yes   NaN
# 15422       I am not primarily a developer, but I write co...      Yes   NaN
# 2932                           I am a developer by profession       No   NaN
# 26540                          I am a developer by profession       No  26.0
# 57269                          I am a developer by profession      Yes  32.0
# 26775                          I am a developer by profession      Yes  23.0
# 30568                          I am a developer by profession       No  24.0
# 30522                          I am a developer by profession      Yes  23.0
# 28811                          I am a developer by profession      Yes  23.0
# 34969                          I am a developer by profession      Yes  15.0
# 26857                          I am a developer by profession       No  25.0
# 33878                          I am a developer by profession      Yes   NaN
# 35753                          I am a developer by profession      Yes   NaN
# 18049                          I am a developer by profession      Yes   NaN
# 35295                          I am a developer by profession      Yes   NaN
# 30608       I used to be a developer by profession, but no...      Yes  20.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 65381                          8   Weekly  8.740000e+09      1000000.0
# 65456       Younger than 5 years   Weekly  5.521171e+09      1000000.0
# 62788                        NaN   Weekly  8.000000e+06      1000000.0
# 38672                          5  Monthly  1.225000e+06       231192.0
# 28374                          7   Yearly  1.300000e+05       130000.0
# 63848                         16  Monthly  1.500000e+05        23328.0
# 9839                          21  Monthly  1.500000e+05        23328.0
# 51862                         10   Weekly  3.234000e+04        20950.0
# 51509                         19  Monthly  1.300000e+05        20220.0
# 44484                         18  Monthly  1.200000e+05        18660.0
# 15422                         23  Monthly  1.500000e+03        18000.0
# 2932                          14   Yearly  6.000000e+04        16335.0
# 26540                         20  Monthly  9.000000e+04        13992.0
# 57269                         19  Monthly  7.000000e+04        10884.0
# 26775                         18  Monthly  1.000000e+03         8016.0
# 30568                         19  Monthly  3.500000e+04         5448.0
# 30522                         19  Monthly  3.000000e+04         4668.0
# 28811                         19   Yearly  3.480000e+05         4509.0
# 34969                         16  Monthly  2.800000e+04         4356.0
# 26857                         20  Monthly  1.500000e+04         2328.0
# 33878                         18  Monthly  1.200000e+04         1860.0
# 35753                         18  Monthly  5.000000e+03          780.0
# 18049                         15   Yearly  1.234500e+04          109.0
# 35295                         13  Monthly  2.000000e+00            0.0
# 30608                         11      NaN           NaN            NaN
#
#                 Country                 CurrencyDesc CurrencySymbol  \
# Respondent
# 65381       Afghanistan               Afghan afghani            AFN
# 65456       Afghanistan               Afghan afghani            AFN
# 62788       Afghanistan                 Albanian lek            ALL
# 38672       Afghanistan                Russian ruble            RUB
# 28374       Afghanistan         United States dollar            USD
# 63848       Afghanistan               Afghan afghani            AFN
# 9839        Afghanistan               Afghan afghani            AFN
# 51862       Afghanistan               Afghan afghani            AFN
# 51509       Afghanistan               Afghan afghani            AFN
# 44484       Afghanistan               Afghan afghani            AFN
# 15422       Afghanistan         United States dollar            USD
# 2932        Afghanistan  United Arab Emirates dirham            AED
# 26540       Afghanistan               Afghan afghani            AFN
# 57269       Afghanistan               Afghan afghani            AFN
# 26775       Afghanistan            Australian dollar            AUD
# 30568       Afghanistan               Afghan afghani            AFN
# 30522       Afghanistan               Afghan afghani            AFN
# 28811       Afghanistan               Afghan afghani            AFN
# 34969       Afghanistan               Afghan afghani            AFN
# 26857       Afghanistan               Afghan afghani            AFN
# 33878       Afghanistan               Afghan afghani            AFN
# 35753       Afghanistan               Afghan afghani            AFN
# 18049       Afghanistan                 Albanian lek            ALL
# 35295       Afghanistan               Afghan afghani            AFN
# 30608       Afghanistan                          NaN            NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                  SQLite
# 63848                                                     NaN
# 9839                                                  MariaDB
# 51862                                            Redis;SQLite
# 51509                                 Couchbase;Elasticsearch
# 44484                                                     NaN
# 15422       Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
# 2932                                                      NaN
# 26540       Couchbase;Elasticsearch;Oracle;PostgreSQL;Redi...
# 57269                       Microsoft SQL Server;MySQL;Oracle
# 26775                                          MariaDB;Oracle
# 30568                                                Firebase
# 30522                                         Firebase;Oracle
# 28811                  Microsoft SQL Server;PostgreSQL;SQLite
# 34969                                                     NaN
# 26857       Firebase;MariaDB;Microsoft SQL Server;MongoDB;...
# 33878                                 Firebase;MongoDB;SQLite
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                                     NaN
# 30608                                    Elasticsearch;SQLite
#
#                                            DatabaseWorkedWith  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                  SQLite
# 63848                                                     NaN
# 9839                                                  MariaDB
# 51862                                            MySQL;SQLite
# 51509                                         MariaDB;MongoDB
# 44484                                                     NaN
# 15422       DynamoDB;Firebase;MariaDB;Microsoft SQL Server...
# 2932                                            MongoDB;MySQL
# 26540       Elasticsearch;MariaDB;Microsoft SQL Server;Mon...
# 57269                       Microsoft SQL Server;MySQL;Oracle
# 26775                  Microsoft SQL Server;PostgreSQL;SQLite
# 30568                                                   MySQL
# 30522       MariaDB;Microsoft SQL Server;MongoDB;MySQL;SQLite
# 28811                                                 MariaDB
# 34969                              Microsoft SQL Server;MySQL
# 26857               MariaDB;Microsoft SQL Server;MySQL;Oracle
# 33878              Firebase;Microsoft SQL Server;MySQL;SQLite
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                 MySQL;PostgreSQL;SQLite
# 30608              Firebase;Microsoft SQL Server;MySQL;Oracle
#
#                                                       DevType  \
# Respondent
# 65381       Data or business analyst;Data scientist or mac...
# 65456                                                     NaN
# 62788                                               Scientist
# 38672                                                     NaN
# 28374       Developer, desktop or enterprise applications;...
# 63848       Academic researcher;Data scientist or machine ...
# 9839        Developer, back-end;Developer, front-end;Devel...
# 51862       Designer;Developer, back-end;Developer, deskto...
# 51509       Developer, back-end;Developer, front-end;Devel...
# 44484       Academic researcher;Data or business analyst;D...
# 15422       Academic researcher;Data or business analyst;D...
# 2932        Database administrator;Developer, back-end;Dev...
# 26540       Academic researcher;Database administrator;Des...
# 57269       Data or business analyst;Database administrato...
# 26775       Database administrator;Developer, back-end;Dev...
# 30568                                     Engineering manager
# 30522       Designer;Developer, back-end;Developer, front-end
# 28811       Developer, back-end;Developer, front-end;Devel...
# 34969       Database administrator;Developer, back-end;Dev...
# 26857                                   Developer, full-stack
# 33878       Database administrator;Designer;Developer, bac...
# 35753       Database administrator;Developer, back-end;Dev...
# 18049       Data scientist or machine learning specialist;...
# 35295                  Academic researcher;Educator;Scientist
# 30608       Data or business analyst;Data scientist or mac...
#
#                                                       EdLevel  \
# Respondent
# 65381                  I never completed any formal education
# 65456              Other doctoral degree (Ph.D., Ed.D., etc.)
# 62788                  I never completed any formal education
# 38672                  I never completed any formal education
# 28374              Other doctoral degree (Ph.D., Ed.D., etc.)
# 63848                  I never completed any formal education
# 9839             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 51862       Secondary school (e.g. American high school, G...
# 51509            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 44484         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 15422       Some college/university study without earning ...
# 2932             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 26540            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57269         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 26775            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30568            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 30522            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 28811            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 34969            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 26857            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 33878            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35753            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 18049            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 35295              Other doctoral degree (Ph.D., Ed.D., etc.)
# 30608         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                    Employment  \
# Respondent
# 65381       Independent contractor, freelancer, or self-em...
# 65456                                      Employed full-time
# 62788                                      Employed full-time
# 38672                                                     NaN
# 28374                                      Employed full-time
# 63848                                      Employed full-time
# 9839                                       Employed full-time
# 51862       Independent contractor, freelancer, or self-em...
# 51509                                      Employed full-time
# 44484                                      Employed full-time
# 15422       Independent contractor, freelancer, or self-em...
# 2932                                       Employed full-time
# 26540                                      Employed full-time
# 57269       Independent contractor, freelancer, or self-em...
# 26775       Independent contractor, freelancer, or self-em...
# 30568                                      Employed full-time
# 30522                                      Employed full-time
# 28811                                      Employed full-time
# 34969                                      Employed full-time
# 26857                                      Employed full-time
# 33878                                      Employed part-time
# 35753                                      Employed full-time
# 18049                                      Employed full-time
# 35295       Independent contractor, freelancer, or self-em...
# 30608                                      Employed full-time
#
#                                                     Ethnicity Gender  \
# Respondent
# 65381                                                     NaN    NaN
# 65456                                                     NaN    NaN
# 62788                                                     NaN    NaN
# 38672                                                     NaN    NaN
# 28374                                                     NaN    Man
# 63848                                                     NaN    NaN
# 9839                                           Middle Eastern    Man
# 51862                                                     NaN    Man
# 51509                            White or of European descent    Man
# 44484                                                     NaN    NaN
# 15422       Middle Eastern;White or of European descent;In...    Man
# 2932                                                      NaN    NaN
# 26540                                                     NaN    Man
# 57269                                                     NaN    Man
# 26775                  Black or of African descent;East Asian    Man
# 30568                                          Middle Eastern    Man
# 30522                                              East Asian  Woman
# 28811                                          Middle Eastern    Man
# 34969                                             South Asian    Man
# 26857                                              East Asian    Man
# 33878                                              East Asian    Man
# 35753                                                     NaN    NaN
# 18049                                                     NaN    NaN
# 35295                                                     NaN    NaN
# 30608                                             South Asian  Woman
#
#                                                    JobFactors  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374       Industry that I’d be working in;Specific depar...
# 63848                                                     NaN
# 9839        Languages, frameworks, and other technologies ...
# 51862       Remote work options;How widely used or impactf...
# 51509       Languages, frameworks, and other technologies ...
# 44484                                                     NaN
# 15422       Office environment or company culture;Opportun...
# 2932        Industry that I’d be working in;Diversity of t...
# 26540       Flex time or a flexible schedule;Office enviro...
# 57269       Languages, frameworks, and other technologies ...
# 26775       Industry that I’d be working in;Remote work op...
# 30568       Industry that I’d be working in;How widely use...
# 30522       Languages, frameworks, and other technologies ...
# 28811       Flex time or a flexible schedule;Languages, fr...
# 34969       Industry that I’d be working in;Languages, fra...
# 26857       Languages, frameworks, and other technologies ...
# 33878                                                     NaN
# 35753                                                     NaN
# 18049       Diversity of the company or organization;Speci...
# 35295                                                     NaN
# 30608                                                     NaN
#
#                                         JobSat  \
# Respondent
# 65381                        Very dissatisfied
# 65456                        Very dissatisfied
# 62788                    Slightly dissatisfied
# 38672                           Very satisfied
# 28374                       Slightly satisfied
# 63848                           Very satisfied
# 9839                     Slightly dissatisfied
# 51862                       Slightly satisfied
# 51509                           Very satisfied
# 44484                           Very satisfied
# 15422       Neither satisfied nor dissatisfied
# 2932                            Very satisfied
# 26540                       Slightly satisfied
# 57269       Neither satisfied nor dissatisfied
# 26775                       Slightly satisfied
# 30568                           Very satisfied
# 30522                    Slightly dissatisfied
# 28811                       Slightly satisfied
# 34969                       Slightly satisfied
# 26857                       Slightly satisfied
# 33878                    Slightly dissatisfied
# 35753       Neither satisfied nor dissatisfied
# 18049                       Slightly satisfied
# 35295                        Very dissatisfied
# 30608                                      NaN
#
#                                                       JobSeek  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                         I am actively looking for a job
# 38672                                                     NaN
# 28374            I am not interested in new job opportunities
# 63848                                                     NaN
# 9839                          I am actively looking for a job
# 51862                         I am actively looking for a job
# 51509       I’m not actively looking, but I am open to new...
# 44484                                                     NaN
# 15422       I’m not actively looking, but I am open to new...
# 2932             I am not interested in new job opportunities
# 26540                         I am actively looking for a job
# 57269                         I am actively looking for a job
# 26775       I’m not actively looking, but I am open to new...
# 30568            I am not interested in new job opportunities
# 30522                         I am actively looking for a job
# 28811       I’m not actively looking, but I am open to new...
# 34969       I’m not actively looking, but I am open to new...
# 26857       I’m not actively looking, but I am open to new...
# 33878       I’m not actively looking, but I am open to new...
# 35753                                                     NaN
# 18049       I’m not actively looking, but I am open to new...
# 35295                         I am actively looking for a job
# 30608                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                 Bash/Shell/PowerShell;C
# 63848                                                     NaN
# 9839            HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 51862            C;C++;Go;HTML/CSS;JavaScript;Python;Rust;SQL
# 51509                                                     NaN
# 44484                                                     NaN
# 15422            C#;C++;Java;JavaScript;Python;Ruby;SQL;Swift
# 2932                                                      NaN
# 26540                                    C;C#;C++;Go;Python;R
# 57269                            HTML/CSS;Java;JavaScript;PHP
# 26775                                     Kotlin;Python;Swift
# 30568                                     C#;Dart;Java;Python
# 30522                                                     NaN
# 28811       Bash/Shell/PowerShell;Java;JavaScript;PHP;Pyth...
# 34969                                                     NaN
# 26857            Dart;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 33878                                          Dart;SQL;Swift
# 35753                                                     NaN
# 18049                                               C++;Julia
# 35295                                                     NaN
# 30608                                            R;Ruby;Swift
#
#                                            LanguageWorkedWith  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                        Bash/Shell/PowerShell;C;C++;Java
# 63848                                                     NaN
# 9839                   HTML/CSS;JavaScript;PHP;SQL;TypeScript
# 51862       Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 51509                      HTML/CSS;JavaScript;PHP;TypeScript
# 44484                                                     NaN
# 15422                       Haskell;JavaScript;PHP;Python;SQL
# 2932                                               JavaScript
# 26540       C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript
# 57269                            HTML/CSS;Java;JavaScript;PHP
# 26775            C#;C++;Dart;HTML/CSS;Java;JavaScript;PHP;SQL
# 30568                             HTML/CSS;JavaScript;PHP;SQL
# 30522       C#;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL...
# 28811       Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 34969       Assembly;Bash/Shell/PowerShell;C#;C++;HTML/CSS...
# 26857                             HTML/CSS;JavaScript;PHP;SQL
# 33878                                Dart;Java;Kotlin;PHP;SQL
# 35753                                                     NaN
# 18049                                                     C++
# 35295       Assembly;Bash/Shell/PowerShell;C;C++;Java;Java...
# 30608       Bash/Shell/PowerShell;C#;C++;Dart;HTML/CSS;Jav...
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                     NaN
# 63848                                                     NaN
# 9839                                                  Node.js
# 51862       Cordova;Node.js;TensorFlow;Unity 3D;Unreal Engine
# 51509                                                 Node.js
# 44484                                                     NaN
# 15422                               .NET;Node.js;React Native
# 2932                                                      NaN
# 26540                          .NET Core;Node.js;React Native
# 57269                                                    .NET
# 26775                                        Node.js;Unity 3D
# 30568                                                     NaN
# 30522                                                 Flutter
# 28811                          .NET Core;Node.js;React Native
# 34969                         Node.js;React Native;TensorFlow
# 26857                                         Flutter;Node.js
# 33878                     Flutter;Node.js;TensorFlow;Unity 3D
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                                     NaN
# 30608                                                     NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                     NaN
# 63848                                                     NaN
# 9839                                                  Node.js
# 51862       Cordova;Node.js;TensorFlow;Unity 3D;Unreal Eng...
# 51509                                                     NaN
# 44484                                                     NaN
# 15422                                                 Node.js
# 2932                                     Node.js;React Native
# 26540                                                 Node.js
# 57269                                             .NET;Pandas
# 26775                                                     NaN
# 30568                                                     NaN
# 30522                                            .NET;Node.js
# 28811                                       .NET Core;Node.js
# 34969                                           Torch/PyTorch
# 26857                                                 Node.js
# 33878                                                 Flutter
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                     TensorFlow;Unity 3D
# 30608       .NET;.NET Core;Apache Spark;Flutter;Pandas;Rea...
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                    Jira
# 63848                                                     NaN
# 9839                                                   Gitlab
# 51862                   Github;Google Suite (Docs, Meet, etc)
# 51509                                                  Gitlab
# 44484                                                     NaN
# 15422       Github;Facebook Workplace;Microsoft Teams;Micr...
# 2932                                                      NaN
# 26540       Facebook Workplace;Google Suite (Docs, Meet, e...
# 57269                                Stack Overflow for Teams
# 26775                                Stack Overflow for Teams
# 30568         Github;Facebook Workplace;Slack;Microsoft Teams
# 30522                                                     NaN
# 28811       Jira;Slack;Google Suite (Docs, Meet, etc);Stac...
# 34969       Github;Gitlab;Slack;Microsoft Teams;Stack Over...
# 26857                                                  Github
# 33878                                                  Github
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                                     NaN
# 30608                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 65381                                                     NaN       Yes
# 65456                                                     NaN       NaN
# 62788                                                     NaN       NaN
# 38672                                                     NaN       NaN
# 28374                                      Jira;Github;Trello       Yes
# 63848                                                     NaN       NaN
# 9839                                                   Gitlab       Yes
# 51862       Github;Gitlab;Trello;Google Suite (Docs, Meet,...  Not sure
# 51509                                                  Gitlab  Not sure
# 44484                                                     NaN        No
# 15422                   Github;Google Suite (Docs, Meet, etc)  Not sure
# 2932                                                   Gitlab        No
# 26540       Github;Gitlab;Trello;Google Suite (Docs, Meet,...       Yes
# 57269                                Stack Overflow for Teams        No
# 26775                                                  Github  Not sure
# 30568                                            Github;Slack        No
# 30522       Github;Gitlab;Trello;Google Suite (Docs, Meet,...       Yes
# 28811                                                  Github        No
# 34969                                                     NaN        No
# 26857                                                  Github  Not sure
# 33878                                                  Github       Yes
# 35753                                                     NaN       NaN
# 18049                                                     NaN       Yes
# 35295                                                     NaN       NaN
# 30608       Github;Facebook Workplace;Slack;Microsoft Team...       NaN
#
#                    NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 65381       Not at all important                                 NaN
# 65456                        NaN  Not at all important/not necessary
# 62788         Somewhat important                                 NaN
# 38672                        NaN                                 NaN
# 28374         Somewhat important                    Fairly important
# 63848                        NaN                                 NaN
# 9839          Somewhat important                      Very important
# 51862                    Neutral                    Fairly important
# 51509         Somewhat important                    Fairly important
# 44484        Extremely important                      Very important
# 15422        Extremely important                    Fairly important
# 2932         Extremely important                      Very important
# 26540         Somewhat important                    Fairly important
# 57269                    Neutral                Critically important
# 26775         Not very important                      Very important
# 30568         Somewhat important                      Very important
# 30522         Somewhat important                    Fairly important
# 28811         Somewhat important                  Somewhat important
# 34969                    Neutral                    Fairly important
# 26857         Somewhat important                Critically important
# 33878        Extremely important                    Fairly important
# 35753                        NaN                    Fairly important
# 18049        Extremely important                      Very important
# 35295                        NaN                      Very important
# 30608                        NaN                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                       Curious about other opportunities
# 38672                                                     NaN
# 28374       Having a bad day (or week or month) at work;Cu...
# 63848                                                     NaN
# 9839        Having a bad day (or week or month) at work;Wa...
# 51862       Just because;Curious about other opportunities...
# 51509       Better compensation;Trouble with leadership at...
# 44484                                                     NaN
# 15422       Having a bad day (or week or month) at work;Wa...
# 2932        Just because;Having a bad day (or week or mont...
# 26540       Better work/life balance;Wanting to work with ...
# 57269       Wanting to share accomplishments with a wider ...
# 26775                               Trouble with my teammates
# 30568                      Growth or leadership opportunities
# 30522       Curious about other opportunities;Wanting to w...
# 28811       Wanting to share accomplishments with a wider ...
# 34969       Curious about other opportunities;Trouble with...
# 26857       Wanting to share accomplishments with a wider ...
# 33878       Wanting to work with new technologies;Growth o...
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                                     NaN
# 30608                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374       Publicly available financial information (e.g....
# 63848                                                     NaN
# 9839        Read company media, such as employee blogs or ...
# 51862       Read company media, such as employee blogs or ...
# 51509       Read other media like news articles, founder p...
# 44484                                                     NaN
# 15422       Read company media, such as employee blogs or ...
# 2932        Read company media, such as employee blogs or ...
# 26540       Company reviews from third party sites (e.g. G...
# 57269       Read company media, such as employee blogs or ...
# 26775                    Personal network - friends or family
# 30568       Personal network - friends or family;Read othe...
# 30522       Read company media, such as employee blogs or ...
# 28811       Read company media, such as employee blogs or ...
# 34969       Directly asking current or past employees at t...
# 26857       Read company media, such as employee blogs or ...
# 33878                                                     NaN
# 35753                                                     NaN
# 18049       Company reviews from third party sites (e.g. G...
# 35295                                                     NaN
# 30608                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 65381                        NaN         NaN  Onboarding? What onboarding?
# 65456                        NaN         NaN                           NaN
# 62788                Once a year         NaN                           Yes
# 38672                        NaN         NaN                           NaN
# 28374                        NaN         Yes                           Yes
# 63848                        NaN         NaN                           NaN
# 9839        Once every few years          No                            No
# 51862                        NaN    Not sure  Onboarding? What onboarding?
# 51509       Once every few years    Not sure                           Yes
# 44484                        NaN         NaN                            No
# 15422           Every few months         NaN                            No
# 2932        Once every few years         Yes                           Yes
# 26540           Every few months    Not sure                           Yes
# 57269           Every few months         NaN                           Yes
# 26775                Once a year         Yes                           Yes
# 30568           Every few months    Not sure                           Yes
# 30522                Once a year         Yes                            No
# 28811           Every few months    Not sure  Onboarding? What onboarding?
# 34969           Every few months    Not sure                           Yes
# 26857                Once a year          No                           Yes
# 33878           Every few months         NaN                           Yes
# 35753                        NaN    Not sure  Onboarding? What onboarding?
# 18049                        NaN          No                           Yes
# 35295                Once a year         Yes  Onboarding? What onboarding?
# 30608           Every few months          No                           NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 65381                NaN                                              Never
# 65456                NaN                                                NaN
# 62788                 No                   Often: 1-2 days per week or more
# 38672                NaN                                                NaN
# 28374                Yes  Occasionally: 1-2 days per quarter but less th...
# 63848                NaN                                                NaN
# 9839                  No                   Often: 1-2 days per week or more
# 51862                 No                   Often: 1-2 days per week or more
# 51509                 No                   Often: 1-2 days per week or more
# 44484                NaN                   Often: 1-2 days per week or more
# 15422                 No                   Often: 1-2 days per week or more
# 2932                  No                   Often: 1-2 days per week or more
# 26540                Yes  Sometimes: 1-2 days per month but less than we...
# 57269                 No                   Often: 1-2 days per week or more
# 26775                 No                   Often: 1-2 days per week or more
# 30568                Yes                   Often: 1-2 days per week or more
# 30522                 No                                              Never
# 28811                Yes                  Rarely: 1-2 days per year or less
# 34969                 No                   Often: 1-2 days per week or more
# 26857                Yes                   Often: 1-2 days per week or more
# 33878                Yes                   Often: 1-2 days per week or more
# 35753                Yes                   Often: 1-2 days per week or more
# 18049                Yes                  Rarely: 1-2 days per year or less
# 35295                Yes                   Often: 1-2 days per week or more
# 30608                Yes                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374       Visit developer communities like Stack Overflo...
# 63848                                                     NaN
# 9839        Start a free trial;Ask developers I know/work ...
# 51862       Start a free trial;Visit developer communities...
# 51509                                                     NaN
# 44484                                                     NaN
# 15422       Start a free trial;Visit developer communities...
# 2932        Read ratings or reviews on third party sites l...
# 26540       Start a free trial;Visit developer communities...
# 57269                                      Start a free trial
# 26775       Start a free trial;Ask developers I know/work ...
# 30568                                      Start a free trial
# 30522                                                     NaN
# 28811       Start a free trial;Ask developers I know/work ...
# 34969                                                     NaN
# 26857                                                     NaN
# 33878                                                     NaN
# 35753                                                     NaN
# 18049                                      Start a free trial
# 35295       Read ratings or reviews on third party sites l...
# 30608       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 65381                     NaN
# 65456                     NaN
# 62788                     NaN
# 38672                     NaN
# 28374       Hello, old friend
# 63848                     NaN
# 9839              Indifferent
# 51862       Hello, old friend
# 51509                  Amused
# 44484                     NaN
# 15422                 Annoyed
# 2932        Hello, old friend
# 26540             Indifferent
# 57269                  Amused
# 26775                  Amused
# 30568                 Annoyed
# 30522                  Amused
# 28811       Hello, old friend
# 34969       Hello, old friend
# 26857                  Amused
# 33878       Hello, old friend
# 35753                     NaN
# 18049                  Amused
# 35295       Hello, old friend
# 30608       Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788       Stack Exchange (public Q&A for a variety of to...
# 38672                                                     NaN
# 28374       Stack Overflow (public Q&A for anyone who code...
# 63848                                                     NaN
# 9839        Stack Overflow (public Q&A for anyone who code...
# 51862       Stack Overflow (public Q&A for anyone who code...
# 51509       Stack Overflow (public Q&A for anyone who code...
# 44484                                                     NaN
# 15422       Stack Overflow (public Q&A for anyone who code...
# 2932         Stack Overflow (public Q&A for anyone who codes)
# 26540       Stack Overflow (public Q&A for anyone who code...
# 57269       Stack Overflow Talent (for hiring companies/re...
# 26775        Stack Overflow (public Q&A for anyone who codes)
# 30568       Stack Overflow (public Q&A for anyone who code...
# 30522       Stack Overflow (public Q&A for anyone who code...
# 28811       Stack Overflow (public Q&A for anyone who code...
# 34969       Stack Overflow (public Q&A for anyone who code...
# 26857       Stack Overflow (public Q&A for anyone who code...
# 33878       Stack Overflow (public Q&A for anyone who code...
# 35753       Stack Overflow (public Q&A for anyone who code...
# 18049       Stack Overflow (public Q&A for anyone who code...
# 35295       Stack Overflow (public Q&A for anyone who code...
# 30608       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 65381                                                     NaN          NaN
# 65456                                                     NaN          NaN
# 62788                                                     NaN          NaN
# 38672                                                     NaN          NaN
# 28374          Call a coworker or friend;Visit Stack Overflow          NaN
# 63848                                                     NaN          NaN
# 9839        Visit Stack Overflow;Watch help / tutorial videos          NaN
# 51862       Play games;Visit Stack Overflow;Go for a walk ...          NaN
# 51509                           Meditate;Visit Stack Overflow      Windows
# 44484                                                     NaN          NaN
# 15422       Visit Stack Overflow;Watch help / tutorial vid...      Windows
# 2932        Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 26540       Meditate;Call a coworker or friend;Visit Stack...  Linux-based
# 57269                                    Visit Stack Overflow          NaN
# 26775                                    Visit Stack Overflow      Windows
# 30568       Call a coworker or friend;Visit Stack Overflow...      Windows
# ...
# 9839                   I have some influence  Straight / Heterosexual
# 51862                                    NaN  Straight / Heterosexual
# 51509          I have little or no influence  Straight / Heterosexual
# 44484                                    NaN                      NaN
# 15422                                    NaN                 Bisexual
# 2932        I have a great deal of influence                      NaN
# 26540                  I have some influence                      NaN
# 57269                                    NaN  Straight / Heterosexual
# 26775                                    NaN                 Bisexual
# 30568       I have a great deal of influence                      NaN
# 30522          I have little or no influence                      NaN
# 28811                  I have some influence                      NaN
# 34969          I have little or no influence                      NaN
# 26857          I have little or no influence  Straight / Heterosexual
# 33878          I have little or no influence                      NaN
# 35753                                    NaN                      NaN
# 18049       I have a great deal of influence                      NaN
# 35295                                    NaN                      NaN
# 30608                                    NaN                 Bisexual
#
#            SOAccount           SOComm  \
# Respondent
# 65381            NaN              NaN
# 65456            NaN              NaN
# 62788            NaN              NaN
# 38672            NaN              NaN
# 28374             No   No, not really
# 63848            NaN              NaN
# 9839             Yes   No, not really
# 51862            Yes          Neutral
# 51509            Yes  Yes, definitely
# 44484            NaN              NaN
# 15422            Yes    Yes, somewhat
# 2932              No   No, not at all
# 26540            Yes          Neutral
# 57269            NaN              NaN
# 26775            Yes  Yes, definitely
# 30568            Yes  Yes, definitely
# 30522            Yes    Yes, somewhat
# 28811            Yes    Yes, somewhat
# 34969            Yes   No, not really
# 26857            Yes  Yes, definitely
# 33878            Yes  Yes, definitely
# 35753            Yes  Yes, definitely
# 18049            Yes    Yes, somewhat
# 35295            Yes   No, not at all
# 30608            Yes          Neutral
#
#                                                    SOPartFreq  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                     NaN
# 63848                                                     NaN
# 9839                      Less than once per month or monthly
# 51862                     Less than once per month or monthly
# 51509                                    A few times per week
# 44484                                                     NaN
# 15422                     Less than once per month or monthly
# 2932                                                      NaN
# 26540       I have never participated in Q&A on Stack Over...
# 57269                                                     NaN
# 26775                         A few times per month or weekly
# 30568                     Less than once per month or monthly
# 30522                         A few times per month or weekly
# 28811                                    A few times per week
# 34969       I have never participated in Q&A on Stack Over...
# 26857       I have never participated in Q&A on Stack Over...
# 33878       I have never participated in Q&A on Stack Over...
# 35753                     Less than once per month or monthly
# 18049                                    A few times per week
# 35295                     Less than once per month or monthly
# 30608                     Less than once per month or monthly
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 65381                                   NaN                         NaN
# 65456                                   NaN                         NaN
# 62788                                   NaN                         NaN
# 38672                                   NaN                         NaN
# 28374                Multiple times per day  Neither easy nor difficult
# 63848                                   NaN                         NaN
# 9839                  Daily or almost daily                        Easy
# 51862                Multiple times per day                        Easy
# 51509                Multiple times per day                        Easy
# 44484                                   NaN                         NaN
# 15422                  A few times per week                        Easy
# 2932                 Multiple times per day                        Easy
# 26540                  A few times per week                        Easy
# 57269                                   NaN  Neither easy nor difficult
# 26775                Multiple times per day  Neither easy nor difficult
# 30568       A few times per month or weekly                        Easy
# 30522                 Daily or almost daily                        Easy
# 28811                 Daily or almost daily  Neither easy nor difficult
# 34969                Multiple times per day  Neither easy nor difficult
# 26857                Multiple times per day                        Easy
# 33878                  A few times per week  Neither easy nor difficult
# 35753                 Daily or almost daily                         NaN
# 18049                 Daily or almost daily                         NaN
# 35295                Multiple times per day  Neither easy nor difficult
# 30608       A few times per month or weekly                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 65381                         NaN   NaN
# 65456                         NaN   NaN
# 62788                         NaN   NaN
# 38672                         NaN   NaN
# 28374       Appropriate in length    No
# 63848                         NaN   NaN
# 9839                     Too long    No
# 51862       Appropriate in length    No
# 51509       Appropriate in length    No
# 44484                         NaN   NaN
# 15422       Appropriate in length    No
# 2932        Appropriate in length   NaN
# 26540       Appropriate in length    No
# 57269                    Too long    No
# 26775                    Too long    No
# 30568       Appropriate in length    No
# 30522       Appropriate in length    No
# 28811       Appropriate in length    No
# 34969                    Too long    No
# 26857       Appropriate in length    No
# 33878       Appropriate in length   NaN
# 35753                         NaN   NaN
# 18049                         NaN   NaN
# 35295       Appropriate in length   NaN
# 30608       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 65381                                                     NaN
# 65456       Information systems, information technology, o...
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                               Mathematics or statistics
# 63848                                                     NaN
# 9839        Computer science, computer engineering, or sof...
# 51862                                                     NaN
# 51509       Computer science, computer engineering, or sof...
# 44484       Computer science, computer engineering, or sof...
# 15422       Computer science, computer engineering, or sof...
# 2932        Another engineering discipline (such as civil,...
# 26540       Computer science, computer engineering, or sof...
# 57269       Computer science, computer engineering, or sof...
# 26775       Computer science, computer engineering, or sof...
# 30568       Computer science, computer engineering, or sof...
# 30522       Computer science, computer engineering, or sof...
# 28811       Computer science, computer engineering, or sof...
# 34969       Computer science, computer engineering, or sof...
# 26857       Computer science, computer engineering, or sof...
# 33878       Computer science, computer engineering, or sof...
# 35753       Computer science, computer engineering, or sof...
# 18049       Computer science, computer engineering, or sof...
# 35295       Another engineering discipline (such as civil,...
# 30608       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 65381                                                     NaN
# 65456                                                     NaN
# 62788                                                     NaN
# 38672                                                     NaN
# 28374                                                     NaN
# 63848                                                     NaN
# 9839                                           Django;Laravel
# 51862                    Express;Flask;jQuery;React.js;Vue.js
# 51509                                         Angular;Express
# 44484                                                     NaN
# 15422       Angular.js;ASP.NET;Gatsby;jQuery;Laravel;React...
# 2932                                                      NaN
# 26540                     ASP.NET Core;Drupal;React.js;Vue.js
# 57269                                                     NaN
# 26775                 Angular;Angular.js;ASP.NET;ASP.NET Core
# 30568                                           Django;Vue.js
# 30522                                 React.js;Symfony;Vue.js
# 28811       Angular.js;ASP.NET Core;jQuery;Laravel;React.j...
# 34969                               Angular;Angular.js;Vue.js
# 26857                                   jQuery;Laravel;Vue.js
# 33878                Angular;Angular.js;jQuery;Laravel;Vue.js
# 35753                                                     NaN
# 18049                                                     NaN
# 35295                                                     NaN
# 30608                                                 Angular
#
#                                          WebframeWorkedWith  \
# Respondent
# 65381                                                   NaN
# 65456                                                   NaN
# 62788                                                   NaN
# 38672                                                   NaN
# 28374                                                   NaN
# 63848                                                   NaN
# 9839                                Angular;Express;Laravel
# 51862       Angular.js;Django;Express;Flask;jQuery;React.js
# 51509                                               Angular
# 44484                                                   NaN
# 15422             Angular.js;Drupal;Gatsby;Laravel;React.js
# 2932                                                    NaN
# 26540                        Angular;Express;jQuery;Laravel
# 57269                                                jQuery
# 26775                                        jQuery;Laravel
# 30568                                                jQuery
# 30522                        Angular;ASP.NET;jQuery;Laravel
# 28811                                        jQuery;Laravel
# 34969            ASP.NET;ASP.NET Core;Django;jQuery;Laravel
# 26857                                 jQuery;Laravel;Vue.js
# 33878                                                jQuery
# 35753                                                   NaN
# 18049                                                   NaN
# 35295                                                jQuery
# 30608                         ASP.NET;Django;jQuery;Laravel
#
#                                        WelcomeChange  WorkWeekHrs  \
# Respondent
# 65381                                            NaN          4.0
# 65456                                            NaN          NaN
# 62788                                            NaN          NaN
# 38672                                            NaN          NaN
# 28374        Just as welcome now as I felt last year          NaN
# 63848                                            NaN          NaN
# 9839         Just as welcome now as I felt last year         60.0
# 51862       Somewhat more welcome now than last year         28.0
# 51509        Just as welcome now as I felt last year         40.0
# 44484                                            NaN         60.0
# 15422       Somewhat more welcome now than last year         48.0
# 2932         Just as welcome now as I felt last year         90.0
# 26540       Somewhat more welcome now than last year         48.0
# 57269                                            NaN         52.0
# 26775          A lot more welcome now than last year         35.0
# 30568       Somewhat more welcome now than last year         45.0
# 30522       Somewhat more welcome now than last year         48.0
# 28811       Somewhat more welcome now than last year         43.0
# 34969          A lot more welcome now than last year         48.0
# 26857          A lot more welcome now than last year          8.0
# 33878        Just as welcome now as I felt last year          NaN
# 35753        Just as welcome now as I felt last year          NaN
# 18049          A lot less welcome now than last year          NaN
# 35295          A lot less welcome now than last year        100.0
# 30608       Somewhat less welcome now than last year          NaN
#
#                      YearsCode        YearsCodePro
# Respondent
# 65381                       30                  35
# 65456       More than 50 years  More than 50 years
# 62788                      NaN                 NaN
# 38672                       40                  40
# 28374                       17                   5
# 63848                       14                   5
# 9839                        10                   6
# 51862                        5                   2
# 51509                        8                   5
# 44484                        8                  10
# 15422                        9                   6
# 2932                         4                   2
# 26540                        6                   3
# 57269                        5                   3
# 26775                        3    Less than 1 year
# 30568                        6                   3
# 30522                        5                   3
# 28811                        2                   1
# 34969                        4                   3
# 26857                        5                   1
# 33878                        3                   2
# 35753                        4                   1
# 18049                      NaN                  34
# 35295                       35                  27
# 30608                        7                   2

# %%
df[['Country', 'ConvertedComp']].head(25)
# Out:
#                 Country  ConvertedComp
# Respondent
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 62788       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 63848       Afghanistan        23328.0
# 9839        Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0
# 15422       Afghanistan        18000.0
# 2932        Afghanistan        16335.0
# 26540       Afghanistan        13992.0
# 57269       Afghanistan        10884.0
# 26775       Afghanistan         8016.0
# 30568       Afghanistan         5448.0
# 30522       Afghanistan         4668.0
# 28811       Afghanistan         4509.0
# 34969       Afghanistan         4356.0
# 26857       Afghanistan         2328.0
# 33878       Afghanistan         1860.0
# 35753       Afghanistan          780.0
# 18049       Afghanistan          109.0
# 35295       Afghanistan            0.0
# 30608       Afghanistan            NaN

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 19730    2000000.0
# 35242    2000000.0
# 53155    2000000.0
# 5185     2000000.0
# 36338    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 54263                          I am a developer by profession      Yes  29.0
# 5725                           I am a developer by profession       No  26.0
# 43430                          I am a developer by profession      Yes  33.0
# 59279                          I am a developer by profession      Yes   NaN
# 46711                          I am a developer by profession      Yes   NaN
# 19730                          I am a developer by profession      Yes  37.0
# 35242                          I am a developer by profession      Yes  42.0
# 53155       I am not primarily a developer, but I write co...      Yes  43.0
# 5185                           I am a developer by profession      Yes  44.0
# 36338                          I am a developer by profession      Yes   NaN
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 54263                         10   Weekly  7.000000e+04      2000000.0
# 5725                          14  Monthly  1.800000e+05      2000000.0
# 43430                         17  Monthly  1.710000e+05      2000000.0
# 59279                         12  Monthly  3.000000e+05      2000000.0
# 46711       Younger than 5 years   Yearly  1.000000e+56      2000000.0
# 19730                         10   Weekly  1.000000e+05      2000000.0
# 35242                         10   Weekly  7.500000e+04      2000000.0
# 53155                         10   Weekly  4.992000e+04      2000000.0
# 5185                          10  Monthly  1.850000e+05      2000000.0
# 36338                         10   Weekly  1.200000e+05      2000000.0
#
#                   Country          CurrencyDesc CurrencySymbol  \
# Respondent
# 54263              Canada  United States dollar            USD
# 5725               Canada  United States dollar            USD
# 43430               Italy  United States dollar            USD
# 59279               Nepal  United States dollar            USD
# 46711             Nomadic  United States dollar            USD
# 19730       United States  United States dollar            USD
# 35242       United States  United States dollar            USD
# 53155       United States  United States dollar            USD
# 5185        United States  United States dollar            USD
# 36338       United States  United States dollar            USD
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 54263                                                   Redis
# 5725                                                    Redis
# 43430                                                     NaN
# 59279       Cassandra;Couchbase;DynamoDB;IBM DB2;MariaDB;M...
# 46711       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 19730       Cassandra;Couchbase;MongoDB;MySQL;PostgreSQL;R...
# 35242                                       PostgreSQL;SQLite
# 53155                               MongoDB;PostgreSQL;SQLite
# 5185                          MariaDB;PostgreSQL;Redis;SQLite
# 36338                                                     NaN
#
#                                            DatabaseWorkedWith  \
# Respondent
# 54263                              Firebase;PostgreSQL;SQLite
# 5725                                                      NaN
# 43430                                                     NaN
# 59279       Elasticsearch;Firebase;Microsoft SQL Server;My...
# 46711       Cassandra;Couchbase;DynamoDB;Elasticsearch;Fir...
# 19730                          MongoDB;MySQL;PostgreSQL;Redis
# 35242                         MariaDB;PostgreSQL;Redis;SQLite
# 53155                                                     NaN
# 5185                                MariaDB;PostgreSQL;SQLite
# 36338                                                     NaN
#
#                                                       DevType  \
# Respondent
# 54263                                       Developer, mobile
# 5725                    Developer, back-end;DevOps specialist
# 43430       Academic researcher;Developer, back-end;Develo...
# 59279       Data or business analyst;Data scientist or mac...
# 46711       Academic researcher;Data or business analyst;D...
# 19730                                   Developer, full-stack
# 35242       Developer, embedded applications or devices;De...
# 53155              Developer, front-end;Developer, full-stack
# 5185        Designer;DevOps specialist;Engineer, site reli...
# 36338                                   Developer, full-stack
#
#                                                     EdLevel  \
# Respondent
# 54263          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5725           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43430            Other doctoral degree (Ph.D., Ed.D., etc.)
# 59279       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 46711                             Primary/elementary school
# 19730                    Professional degree (JD, MD, etc.)
# 35242       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 53155          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5185           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36338                   Associate degree (A.A., A.S., etc.)
#
#                     Employment  \
# Respondent
# 54263       Employed full-time
# 5725        Employed full-time
# 43430       Employed full-time
# 59279       Employed full-time
# 46711       Employed full-time
# 19730       Employed full-time
# 35242       Employed full-time
# 53155       Employed full-time
# 5185        Employed full-time
# 36338       Employed full-time
#
#                                                     Ethnicity Gender  \
# Respondent
# 54263                                             South Asian    Man
# 5725                             White or of European descent    Man
# 43430                            White or of European descent    Man
# 59279                             South Asian;Southeast Asian    NaN
# 46711                                                     NaN    NaN
# 19730                                              East Asian    Man
# 35242                            White or of European descent    Man
# 53155       Hispanic or Latino/a/x;White or of European de...    Man
# 5185                             White or of European descent    Man
# 36338                                                     NaN    NaN
#
#                                                    JobFactors  \
# Respondent
# 54263       Flex time or a flexible schedule;Languages, fr...
# 5725        Languages, frameworks, and other technologies ...
# 43430       Languages, frameworks, and other technologies ...
# 59279       Flex time or a flexible schedule;Remote work o...
# 46711       Languages, frameworks, and other technologies ...
# 19730       Flex time or a flexible schedule;Office enviro...
# 35242       Flex time or a flexible schedule;Remote work o...
# 53155       Flex time or a flexible schedule;Languages, fr...
# 5185        Flex time or a flexible schedule;Remote work o...
# 36338                                                     NaN
#
#                                         JobSat  \
# Respondent
# 54263                       Slightly satisfied
# 5725                        Slightly satisfied
# 43430                           Very satisfied
# 59279                           Very satisfied
# 46711                           Very satisfied
# 19730                           Very satisfied
# 35242                           Very satisfied
# 53155                    Slightly dissatisfied
# 5185        Neither satisfied nor dissatisfied
# 36338                           Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 54263       I’m not actively looking, but I am open to new...
# 5725             I am not interested in new job opportunities
# 43430            I am not interested in new job opportunities
# 59279       I’m not actively looking, but I am open to new...
# 46711       I’m not actively looking, but I am open to new...
# 19730            I am not interested in new job opportunities
# 35242            I am not interested in new job opportunities
# 53155                         I am actively looking for a job
# 5185                          I am actively looking for a job
# 36338                                                     NaN
#
#                                        LanguageDesireNextYear  \
# Respondent
# 54263                                         Go;Haskell;Rust
# 5725                                Go;Python;Ruby;TypeScript
# 43430        Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 59279       Dart;Go;Haskell;Julia;Kotlin;Perl;PHP;R;Ruby;R...
# 46711       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 19730       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 35242                                             Perl;Python
# 53155                                              TypeScript
# 5185                 Bash/Shell/PowerShell;Go;HTML/CSS;Python
# 36338                                                     NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 54263           Dart;Java;JavaScript;Kotlin;Python;TypeScript
# 5725                  Bash/Shell/PowerShell;JavaScript;Python
# 43430        Assembly;Bash/Shell/PowerShell;C;C++;Perl;Python
# 59279       Assembly;Bash/Shell/PowerShell;C;C#;C++;HTML/C...
# 46711       Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 19730       Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 35242                                        Java;Perl;Python
# 53155               Bash/Shell/PowerShell;HTML/CSS;JavaScript
# 5185        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Perl...
# 36338                                                     NaN
#
#                                        MiscTechDesireNextYear  \
# Respondent
# 54263                   React Native;TensorFlow;Torch/PyTorch
# 5725                                                 Teraform
# 43430                                                     NaN
# 59279       Ansible;Apache Spark;Flutter;Hadoop;Keras;Pand...
# 46711       .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 19730       .NET Core;Apache Spark;Hadoop;Keras;Node.js;Pa...
# 35242                                            Keras;Puppet
# 53155       .NET;React Native;TensorFlow;Unity 3D;Unreal E...
# 5185        Ansible;Flutter;Node.js;TensorFlow;Teraform;To...
# 36338                                                     NaN
#
#                                            MiscTechWorkedWith  \
# Respondent
# 54263                                         Flutter;Node.js
# 5725                                                      NaN
# 43430                                                     NaN
# 59279       .NET;.NET Core;Chef;Cordova;Node.js;React Nati...
# 46711       .NET;.NET Core;Ansible;Apache Spark;Chef;Cordo...
# 19730                            Node.js;Pandas;Torch/PyTorch
# 35242                                                  Puppet
# 53155                                                     NaN
# 5185        .NET;.NET Core;Ansible;Node.js;Puppet;TensorFl...
# 36338                                                     NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 54263                                      Facebook Workplace
# 5725             Github;Gitlab;Google Suite (Docs, Meet, etc)
# 43430       Confluence;Jira;Github;Gitlab;Slack;Google Sui...
# 59279                                           Gitlab;Trello
# 46711       Confluence;Jira;Github;Gitlab;Facebook Workpla...
# 19730       Github;Gitlab;Slack;Google Suite (Docs, Meet, ...
# 35242                                                  Github
# 53155                                                     NaN
# 5185        Gitlab;Slack;Microsoft Azure;Google Suite (Doc...
# 36338                                                     NaN
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 54263       Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 5725                    Github;Google Suite (Docs, Meet, etc)       Yes
# 43430       Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 59279       Confluence;Jira;Github;Facebook Workplace;Slac...       Yes
# 46711       Confluence;Jira;Github;Gitlab;Facebook Workpla...       Yes
# 19730             Github;Slack;Google Suite (Docs, Meet, etc)        No
# 35242                                                  Github        No
# 53155                                     Github;Slack;Trello        No
# 5185        Confluence;Jira;Github;Gitlab;Slack;Microsoft ...       Yes
# 36338                                                     NaN       NaN
#
#                    NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 54263        Extremely important                  Somewhat important
# 5725         Extremely important                      Very important
# 43430         Somewhat important                    Fairly important
# 59279        Extremely important                                 NaN
# 46711        Extremely important  Not at all important/not necessary
# 19730        Extremely important  Not at all important/not necessary
# 35242                    Neutral                  Somewhat important
# 53155       Not at all important                  Somewhat important
# 5185         Extremely important                  Somewhat important
# 36338                        NaN  Not at all important/not necessary
#
#                                                    NEWJobHunt  \
# Respondent
# 54263       Just because;Curious about other opportunities...
# 5725        Trouble with my teammates;Better work/life bal...
# 43430       Curious about other opportunities;Better compe...
# 59279       Having a bad day (or week or month) at work;Tr...
# 46711       Just because;Having a bad day (or week or mont...
# 19730       Having a bad day (or week or month) at work;Cu...
# 35242                   Wanting to work with new technologies
# 53155       Better compensation;Better work/life balance;G...
# 5185        Just because;Curious about other opportunities...
# 36338                                                     NaN
#
#                                            NEWJobHuntResearch  \
# Respondent
# 54263       Read company media, such as employee blogs or ...
# 5725        Read company media, such as employee blogs or ...
# 43430       Read company media, such as employee blogs or ...
# 59279       Read company media, such as employee blogs or ...
# 46711       Read company media, such as employee blogs or ...
# 19730       Read company media, such as employee blogs or ...
# 35242                                                     NaN
# 53155       Read company media, such as employee blogs or ...
# 5185        Company reviews from third party sites (e.g. G...
# 36338                                                     NaN
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 54263           Every few months    Not sure                           Yes
# 5725                 Once a year          No                           Yes
# 43430       Once every few years    Not sure                           Yes
# 59279                        NaN         Yes                           Yes
# 46711           Every few months         NaN                           Yes
# 19730                Once a year         NaN                           Yes
# 35242                Once a year    Not sure                            No
# 53155       Once every few years    Not sure  Onboarding? What onboarding?
# 5185            Every few months    Not sure  Onboarding? What onboarding?
# 36338                        NaN         NaN                           NaN
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 54263                Yes                  Rarely: 1-2 days per year or less
# 5725                  No                   Often: 1-2 days per week or more
# 43430                 No                   Often: 1-2 days per week or more
# 59279                 No  Sometimes: 1-2 days per month but less than we...
# 46711                NaN                   Often: 1-2 days per week or more
# 19730                Yes                  Rarely: 1-2 days per year or less
# 35242                Yes  Occasionally: 1-2 days per quarter but less th...
# 53155                Yes  Occasionally: 1-2 days per quarter but less th...
# 5185                 Yes                   Often: 1-2 days per week or more
# 36338                NaN                                                NaN
#
#                                           NEWPurchaseResearch  \
# Respondent
# 54263       Start a free trial;Ask developers I know/work ...
# 5725                                                      NaN
# 43430                                      Start a free trial
# 59279       Start a free trial;Ask developers I know/work ...
# 46711                                                     NaN
# 19730       Start a free trial;Ask developers I know/work ...
# 35242                                      Start a free trial
# 53155                         Ask developers I know/work with
# 5185        Ask developers I know/work with;Visit develope...
# 36338                                                     NaN
#
#                 NEWPurpleLink  \
# Respondent
# 54263       Hello, old friend
# 5725        Hello, old friend
# 43430             Indifferent
# 59279                  Amused
# 46711       Hello, old friend
# 19730       Hello, old friend
# 35242                  Amused
# 53155       Hello, old friend
# 5185              Indifferent
# 36338                     NaN
#
#                                                    NEWSOSites  \
# Respondent
# 54263       Stack Overflow (public Q&A for anyone who code...
# 5725        Stack Overflow (public Q&A for anyone who code...
# 43430        Stack Overflow (public Q&A for anyone who codes)
# 59279       Stack Overflow (public Q&A for anyone who code...
# 46711       Stack Overflow (public Q&A for anyone who code...
# 19730       Stack Overflow (public Q&A for anyone who code...
# 35242       Stack Overflow (public Q&A for anyone who code...
# 53155       Stack Overflow (public Q&A for anyone who code...
# 5185        Stack Overflow (public Q&A for anyone who code...
# 36338                                                     NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 54263       Meditate;Visit Stack Overflow;Go for a walk or...        MacOS
# 5725        Call a coworker or friend;Go for a walk or oth...  Linux-based
# 43430       Call a coworker or friend;Go for a walk or oth...  Linux-based
# 59279       Call a coworker or friend;Visit Stack Overflow...      Windows
# 46711       Meditate;Play games;Call a coworker or friend;...          NaN
# 19730       Meditate;Call a coworker or friend;Visit Stack...        MacOS
# 35242       Go for a walk or other physical activity;Do ot...  Linux-based
# 53155       Meditate;Visit Stack Overflow;Go for a walk or...        MacOS
# 5185        Call a coworker or friend;Visit Stack Overflow...        MacOS
# 36338                                                     NaN          NaN
#
#                              OrgSize  \
# Respondent
# 54263                            NaN
# 5725        10,000 or more employees
# 43430       10,000 or more employees
# 59279       1,000 to 4,999 employees
# 46711       10,000 or more employees
# 19730           100 to 499 employees
# 35242             20 to 99 employees
# 53155             20 to 99 employees
# 5185            100 to 499 employees
# 36338             20 to 99 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 54263                            Docker;Heroku;iOS;Kubernetes
# 5725                             Docker;Google Cloud Platform
# 43430                             Android;Linux;MacOS;Windows
# 59279       Arduino;Heroku;IBM Cloud or Watson;Kubernetes;...
# 46711       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 19730                                 Docker;Kubernetes;Linux
# 35242                       Arduino;Docker;Linux;Raspberry Pi
# 53155                                         Linux;WordPress
# 5185        Android;AWS;Docker;Google Cloud Platform;Kuber...
# 36338                                                     NaN
#
#                                            PlatformWorkedWith  \
# Respondent
# 54263                                       Android;AWS;Linux
# 5725                             Docker;Google Cloud Platform
# 43430                             Android;Linux;MacOS;Windows
# 59279       Android;AWS;Docker;Google Cloud Platform;iOS;L...
# 46711       Android;Arduino;AWS;Docker;Google Cloud Platfo...
# 19730                 Docker;Kubernetes;Linux;MacOS;WordPress
# 35242                            Android;Arduino;Docker;Linux
# 53155                                                     NaN
# 5185        AWS;Docker;Google Cloud Platform;Kubernetes;Li...
# 36338                                                     NaN
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 54263                  I have some influence  Straight / Heterosexual
# 5725           I have little or no influence  Straight / Heterosexual
# 43430                  I have some influence  Straight / Heterosexual
# 59279       I have a great deal of influence                      NaN
# 46711          I have little or no influence                      NaN
# 19730                  I have some influence  Straight / Heterosexual
# 35242       I have a great deal of influence                      NaN
# 53155                  I have some influence  Straight / Heterosexual
# 5185        I have a great deal of influence  Straight / Heterosexual
# 36338                                    NaN                      NaN
#
#                           SOAccount          SOComm  \
# Respondent
# 54263       Not sure/can't remember   Yes, somewhat
# 5725                            Yes  No, not at all
# 43430                           Yes  No, not at all
# 59279                           Yes   Yes, somewhat
# 46711                           NaN             NaN
# 19730                            No  No, not really
# 35242                           Yes   Yes, somewhat
# 53155                           Yes   Yes, somewhat
# 5185                            Yes         Neutral
# 36338                           NaN             NaN
#
#                                                    SOPartFreq  \
# Respondent
# 54263                                                     NaN
# 5725        I have never participated in Q&A on Stack Over...
# 43430       I have never participated in Q&A on Stack Over...
# 59279       I have never participated in Q&A on Stack Over...
# 46711                                                     NaN
# 19730                                                     NaN
# 35242                     Less than once per month or monthly
# 53155       I have never participated in Q&A on Stack Over...
# 5185                          A few times per month or weekly
# 36338                                                     NaN
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 54263                 Daily or almost daily  Neither easy nor difficult
# 5725        A few times per month or weekly                        Easy
# 43430       A few times per month or weekly                        Easy
# 59279                Multiple times per day  Neither easy nor difficult
# 46711                Multiple times per day                         NaN
# 19730                 Daily or almost daily                        Easy
# 35242                  A few times per week  Neither easy nor difficult
# 53155       A few times per month or weekly                        Easy
# 5185                 Multiple times per day                        Easy
# 36338                                   NaN                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 54263                    Too long    No
# 5725                    Too short    No
# 43430       Appropriate in length    No
# 59279                    Too long   NaN
# 46711                         NaN   NaN
# 19730                    Too long    No
# 35242       Appropriate in length    No
# 53155                         NaN    No
# 5185        Appropriate in length    No
# 36338                         NaN   NaN
#
#                                                UndergradMajor  \
# Respondent
# 54263       Computer science, computer engineering, or sof...
# 5725        Computer science, computer engineering, or sof...
# 43430       Computer science, computer engineering, or sof...
# 59279       Computer science, computer engineering, or sof...
# 46711                                                     NaN
# 19730       A humanities discipline (such as literature, h...
# 35242                               Mathematics or statistics
# 53155       A humanities discipline (such as literature, h...
# 5185        Computer science, computer engineering, or sof...
# 36338       Information systems, information technology, o...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 54263                                         React.js;Vue.js
# 5725                                                   Gatsby
# 43430                                                     NaN
# 59279                      Django;Drupal;Flask;Gatsby;Laravel
# 46711       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 19730                           Express;Flask;React.js;Vue.js
# 35242                                                     NaN
# 53155                    ASP.NET;Express;Ruby on Rails;Vue.js
# 5185                                         Angular.js;Flask
# 36338                                                     NaN
#
#                                            WebframeWorkedWith  \
# Respondent
# 54263                                    Express;Flask;jQuery
# 5725                                                   Spring
# 43430                                                     NaN
# 59279       Angular;Angular.js;ASP.NET;ASP.NET Core;Expres...
# 46711       Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 19730                                   Flask;React.js;Vue.js
# 35242                                                     NaN
# 53155                                         Gatsby;React.js
# 5185                                               Angular.js
# 36338                                                     NaN
#
#                                                 WelcomeChange  WorkWeekHrs  \
# Respondent
# 54263                 Just as welcome now as I felt last year         36.0
# 5725        Not applicable - I did not use Stack Overflow ...         40.0
# 43430                 Just as welcome now as I felt last year         40.0
# 59279                   A lot more welcome now than last year         40.0
# 46711                                                     NaN        168.0
# 19730                 Just as welcome now as I felt last year         40.0
# 35242                 Just as welcome now as I felt last year         40.0
# 53155                Somewhat more welcome now than last year         40.0
# 5185                  Just as welcome now as I felt last year         60.0
# 36338                                                     NaN          NaN
#
#                      YearsCode        YearsCodePro
# Respondent
# 54263                       14                   5
# 5725                        10                   4
# 43430                       13                   2
# 59279                       20                  14
# 46711       More than 50 years  More than 50 years
# 19730                        2    Less than 1 year
# 35242                       23                  12
# 53155                        5                   2
# 5185                        27                  23
# 36338                       26                  16

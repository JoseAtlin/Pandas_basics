# %%
import pandas as pd
import numpy as np

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col="Respondent")
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col="Column")

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head(5)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 4           I am a developer by profession      Yes   25         18      NaN
# 8           I am a developer by profession      Yes   36         12   Yearly
# 9           I am a developer by profession       No   30         20      NaN
# 10          I am a developer by profession      Yes   22         14   Yearly
# 11          I am a developer by profession      Yes   23         13   Yearly
#
#             CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 4                 NaN            NaN         Albania          Albanian lek
# 8            116000.0       116000.0   United States  United States dollar
# 9                 NaN            NaN         Tunisia  United States dollar
# 10            25000.0        32315.0  United Kingdom        Pound sterling
# 11            31000.0        40070.0  United Kingdom        Pound sterling
#
#            CurrencySymbol       DatabaseDesireNextYear  \
# Respondent
# 4                     ALL                          NaN
# 8                     USD                      MongoDB
# 9                     USD                          NaN
# 10                    GBP         Microsoft SQL Server
# 11                    GBP  Firebase;MongoDB;PostgreSQL
#
#                             DatabaseWorkedWith  \
# Respondent
# 4                                          NaN
# 8                          MariaDB;MySQL;Redis
# 9                                          NaN
# 10                        Microsoft SQL Server
# 11          Firebase;MongoDB;PostgreSQL;SQLite
#
#                                                       DevType  \
# Respondent
# 4                                                         NaN
# 8           Developer, back-end;Developer, desktop or ente...
# 9                                       Developer, full-stack
# 10          Database administrator;Developer, full-stack;D...
# 11          Developer, back-end;Developer, desktop or ente...
#
#                                                     EdLevel  \
# Respondent
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9                        Professional degree (JD, MD, etc.)
# 10          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 4                                                         NaN
# 8                                          Employed full-time
# 9           Independent contractor, freelancer, or self-em...
# 10                                         Employed full-time
# 11                                         Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 4           White or of European descent    Man
# 8           White or of European descent    Man
# 9                                    NaN    Man
# 10          White or of European descent    Man
# 11          White or of European descent    Man
#
#                                                    JobFactors  \
# Respondent
# 4           Flex time or a flexible schedule;Office enviro...
# 8           Remote work options;Opportunities for professi...
# 9           Diversity of the company or organization;Remot...
# 10          Flex time or a flexible schedule;How widely us...
# 11          Flex time or a flexible schedule;Languages, fr...
#
#                            JobSat  \
# Respondent
# 4           Slightly dissatisfied
# 8           Slightly dissatisfied
# 9               Very dissatisfied
# 10                 Very satisfied
# 11          Slightly dissatisfied
#
#                                                       JobSeek  \
# Respondent
# 4           I’m not actively looking, but I am open to new...
# 8           I’m not actively looking, but I am open to new...
# 9           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
# 11                            I am actively looking for a job
#
#                            LanguageDesireNextYear  \
# Respondent
# 4                                             NaN
# 8                                      JavaScript
# 9                                     Python;Rust
# 10          HTML/CSS;Java;JavaScript;Python;R;SQL
# 11                 Go;JavaScript;Swift;TypeScript
#
#                              LanguageWorkedWith MiscTechDesireNextYear  \
# Respondent
# 4                                           NaN                    NaN
# 8                                    Python;SQL               Unity 3D
# 9                       HTML/CSS;JavaScript;PHP                    NaN
# 10          HTML/CSS;Java;JavaScript;Python;SQL      Pandas;TensorFlow
# 11                          C#;JavaScript;Swift   Node.js;React Native
#
#            MiscTechWorkedWith  \
# Respondent
# 4                         NaN
# 8                     Ansible
# 9                         NaN
# 10                     Pandas
# 11                    Node.js
#
#                                 NEWCollabToolsDesireNextYear  \
# Respondent
# 4                                                        NaN
# 8                                                        NaN
# 9                                                        NaN
# 10                                    Github;Microsoft Teams
# 11          Jira;Github;Slack;Google Suite (Docs, Meet, etc)
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 4                                                         NaN        No
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 9           Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
# 10                                     Github;Microsoft Teams        No
# 11          Confluence;Jira;Github;Slack;Microsoft Teams;M...        No
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 4                           NaN  Not at all important/not necessary
# 8           Extremely important  Not at all important/not necessary
# 9                           NaN                      Very important
# 10                      Neutral                    Fairly important
# 11          Extremely important                      Very important
#
#                                                    NEWJobHunt  \
# Respondent
# 4           Curious about other opportunities;Wanting to w...
# 8           Curious about other opportunities;Better compe...
# 9           Curious about other opportunities;Growth or le...
# 10          Curious about other opportunities;Better compe...
# 11          Curious about other opportunities;Better compe...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 4                                                         NaN
# 8           Read company media, such as employee blogs or ...
# 9                                                         NaN
# 10          Company reviews from third party sites (e.g. G...
# 11          Read company media, such as employee blogs or ...
#
#                     NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 4                Once a year    Not sure                           Yes
# 8                Once a year    Not sure                           Yes
# 9                Once a year          No                           Yes
# 10          Every few months         Yes  Onboarding? What onboarding?
# 11          Every few months          No                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 9                     No  Occasionally: 1-2 days per quarter but less th...
# 10                    No                   Often: 1-2 days per week or more
# 11                    No                  Rarely: 1-2 days per year or less
#
#                                           NEWPurchaseResearch  \
# Respondent
# 4                                                         NaN
# 8           Start a free trial;Ask developers I know/work ...
# 9                                          Start a free trial
# 10          Start a free trial;Ask developers I know/work ...
# 11                                                        NaN
#
#                 NEWPurpleLink  \
# Respondent
# 4                         NaN
# 8           Hello, old friend
# 9           Hello, old friend
# 10          Hello, old friend
# 11                    Annoyed
#
#                                                    NEWSOSites  \
# Respondent
# 4           Stack Overflow (public Q&A for anyone who code...
# 8           Stack Overflow (public Q&A for anyone who code...
# 9           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
# 11          Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 4                                                         NaN  Linux-based
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 9                                                    Meditate      Windows
# 10                                       Visit Stack Overflow      Windows
# 11          Play games;Call a coworker or friend;Visit Sta...      Windows
#
#                                                       OrgSize  \
# Respondent
# 4                                          20 to 99 employees
# 8                                          20 to 99 employees
# 9           Just me - I am a freelancer, sole proprietor, ...
# 10                                           2 to 9 employees
# 11                                   10,000 or more employees
#
#                         PlatformDesireNextYear  \
# Respondent
# 4                                          NaN
# 8              iOS;Slack Apps and Integrations
# 9                                          NaN
# 10          Android;Linux;Raspberry Pi;Windows
# 11                        AWS;Docker;iOS;MacOS
#
#                             PlatformWorkedWith  \
# Respondent
# 4                                          NaN
# 8                                       Docker
# 9                                    WordPress
# 10          Android;Linux;Raspberry Pi;Windows
# 11                              AWS;Heroku;iOS
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 4           I have a great deal of influence  Straight / Heterosexual
# 8                      I have some influence  Straight / Heterosexual
# 9                                        NaN  Straight / Heterosexual
# 10          I have a great deal of influence  Straight / Heterosexual
# 11             I have little or no influence  Straight / Heterosexual
#
#            SOAccount           SOComm  \
# Respondent
# 4                Yes  Yes, definitely
# 8                Yes   No, not really
# 9                Yes  Yes, definitely
# 10               Yes  Yes, definitely
# 11               Yes    Yes, somewhat
#
#                                                    SOPartFreq  \
# Respondent
# 4                             A few times per month or weekly
# 8                         Less than once per month or monthly
# 9                                      Multiple times per day
# 10                                     Multiple times per day
# 11          I have never participated in Q&A on Stack Over...
#
#                        SOVisitFreq                  SurveyEase  \
# Respondent
# 4           Multiple times per day                         NaN
# 8           Multiple times per day                        Easy
# 9           Multiple times per day  Neither easy nor difficult
# 10          Multiple times per day                        Easy
# 11          Multiple times per day                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 4                             NaN    No
# 8           Appropriate in length    No
# 9           Appropriate in length    No
# 10          Appropriate in length    No
# 11          Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 4           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                  Mathematics or statistics
# 11          Computer science, computer engineering, or sof...
#
#              WebframeDesireNextYear                  WebframeWorkedWith  \
# Respondent
# 4                               NaN                                 NaN
# 8            Django;React.js;Vue.js                               Flask
# 9                        Angular.js                              jQuery
# 10                     Flask;jQuery                        Flask;jQuery
# 11          Angular;Django;React.js  Angular;Angular.js;Django;React.js
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 4           Somewhat less welcome now than last year         40.0         7
# 8            Just as welcome now as I felt last year         39.0        17
# 9            Just as welcome now as I felt last year         50.0         6
# 10          Somewhat more welcome now than last year         36.0         8
# 11           Just as welcome now as I felt last year         40.0        10
#
#            YearsCodePro
# Respondent
# 4                     4
# 8                    13
# 9                     4
# 10                    4
# 11                    2

# %%
df.dropna(axis='index', how='any')
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 10          I am a developer by profession      Yes   22         14   Yearly
# 33          I am a developer by profession      Yes   39         14  Monthly
# 42          I am a developer by profession       No   32         14   Yearly
# 47          I am a developer by profession      Yes   53         10   Yearly
# 69          I am a developer by profession      Yes   25         12   Yearly
# ...                                    ...      ...  ...        ...      ...
# 62863       I am a developer by profession      Yes   30         11   Yearly
# 62886       I am a developer by profession      Yes   32         24   Yearly
# 62904       I am a developer by profession      Yes   33         24   Yearly
# 63288       I am a developer by profession       No   31         16   Yearly
# 64938       I am a developer by profession       No   33         13   Yearly
#
#             CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 10            25000.0        32315.0  United Kingdom        Pound sterling
# 33             4900.0        63564.0         Belgium         European Euro
# 42           130000.0       130000.0   United States  United States dollar
# 47            58000.0        74970.0  United Kingdom        Pound sterling
# 69           550000.0       594539.0          France         European Euro
# ...               ...            ...             ...                   ...
# 62863        230000.0       230000.0   United States  United States dollar
# 62886        102700.0       102700.0   United States  United States dollar
# 62904         95000.0        95000.0   United States  United States dollar
# 63288         65000.0        84019.0  United Kingdom        Pound sterling
# 64938         55000.0        59454.0          France         European Euro
#
#            CurrencySymbol                  DatabaseDesireNextYear  \
# Respondent
# 10                    GBP                    Microsoft SQL Server
# 33                    EUR                                 MongoDB
# 42                    USD              Cassandra;DynamoDB;MongoDB
# 47                    GBP                       PostgreSQL;SQLite
# 69                    EUR                              PostgreSQL
# ...                   ...                                     ...
# 62863                 USD                MongoDB;PostgreSQL;Redis
# 62886                 USD                                   Redis
# 62904                 USD                      MongoDB;PostgreSQL
# 63288                 GBP                                 MongoDB
# 64938                 EUR  Elasticsearch;MongoDB;PostgreSQL;Redis
#
#                                            DatabaseWorkedWith  \
# Respondent
# 10                                       Microsoft SQL Server
# 33                            MongoDB;MySQL;PostgreSQL;SQLite
# 42                    Microsoft SQL Server;MySQL;Oracle;Redis
# 47              Microsoft SQL Server;Oracle;PostgreSQL;SQLite
# 69                                                    MongoDB
# ...                                                       ...
# 62863                                MongoDB;PostgreSQL;Redis
# 62886                              Microsoft SQL Server;Redis
# 62904       MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 63288                                                 MongoDB
# 64938       DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;Po...
#
#                                                       DevType  \
# Respondent
# 10          Database administrator;Developer, full-stack;D...
# 33          Developer, front-end;Developer, full-stack;Dev...
# 42          Developer, back-end;Developer, desktop or ente...
# 47          Data scientist or machine learning specialist;...
# 69          Data scientist or machine learning specialist;...
# ...                                                       ...
# 62863       Developer, back-end;Developer, desktop or ente...
# 62886       Developer, back-end;Developer, front-end;Devel...
# 62904       Developer, back-end;Developer, desktop or ente...
# 63288       Designer;Developer, back-end;Developer, front-...
# 64938                   Developer, back-end;DevOps specialist
#
#                                                     EdLevel  \
# Respondent
# 10          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 33             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 42             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 47               Other doctoral degree (Ph.D., Ed.D., etc.)
# 69          Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...                                                     ...
# 62863          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 62886       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 62904                   Associate degree (A.A., A.S., etc.)
# 63288          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64938                    Professional degree (JD, MD, etc.)
#
#                     Employment  \
# Respondent
# 10          Employed full-time
# 33          Employed full-time
# 42          Employed full-time
# 47          Employed full-time
# 69          Employed full-time
# ...                        ...
# 62863       Employed full-time
# 62886       Employed full-time
# 62904       Employed full-time
# 63288       Employed full-time
# 64938       Employed full-time
#
#                                                     Ethnicity Gender  \
# Respondent
# 10                               White or of European descent    Man
# 33                               White or of European descent    Man
# 42                               White or of European descent    Man
# 47                               White or of European descent    Man
# 69                               White or of European descent    Man
# ...                                                       ...    ...
# 62863                            White or of European descent    Man
# 62886                            White or of European descent    Man
# 62904                            White or of European descent    Man
# 63288       Hispanic or Latino/a/x;White or of European de...    Man
# 64938                            White or of European descent  Woman
#
#                                                    JobFactors  \
# Respondent
# 10          Flex time or a flexible schedule;How widely us...
# 33          Flex time or a flexible schedule;Remote work o...
# 42          Remote work options;How widely used or impactf...
# 47          Remote work options;How widely used or impactf...
# 69          Flex time or a flexible schedule;How widely us...
# ...                                                       ...
# 62863       Flex time or a flexible schedule;Languages, fr...
# 62886       Languages, frameworks, and other technologies ...
# 62904       Languages, frameworks, and other technologies ...
# 63288       Flex time or a flexible schedule;Languages, fr...
# 64938       Flex time or a flexible schedule;Office enviro...
#
#                            JobSat  \
# Respondent
# 10                 Very satisfied
# 33          Slightly dissatisfied
# 42                 Very satisfied
# 47                 Very satisfied
# 69                 Very satisfied
# ...                           ...
# 62863          Slightly satisfied
# 62886          Slightly satisfied
# 62904          Slightly satisfied
# 63288              Very satisfied
# 64938              Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 10          I’m not actively looking, but I am open to new...
# 33          I’m not actively looking, but I am open to new...
# 42          I’m not actively looking, but I am open to new...
# 47          I’m not actively looking, but I am open to new...
# 69               I am not interested in new job opportunities
# ...                                                       ...
# 62863            I am not interested in new job opportunities
# 62886            I am not interested in new job opportunities
# 62904       I’m not actively looking, but I am open to new...
# 63288       I’m not actively looking, but I am open to new...
# 64938            I am not interested in new job opportunities
#
#                                        LanguageDesireNextYear  \
# Respondent
# 10                      HTML/CSS;Java;JavaScript;Python;R;SQL
# 33                             HTML/CSS;JavaScript;TypeScript
# 42               Bash/Shell/PowerShell;C#;Go;Java;Python;Rust
# 47                      Bash/Shell/PowerShell;Java;Python;SQL
# 69                                      Python;Rust;Scala;SQL
# ...                                                       ...
# 62863                      HTML/CSS;JavaScript;SQL;TypeScript
# 62886                                  C#;HTML/CSS;TypeScript
# 62904                           Dart;Go;JavaScript;TypeScript
# 63288       HTML/CSS;JavaScript;Kotlin;Python;Rust;TypeScript
# 64938                                         Go;Python;R;SQL
#
#                                            LanguageWorkedWith  \
# Respondent
# 10                        HTML/CSS;Java;JavaScript;Python;SQL
# 33                             HTML/CSS;JavaScript;TypeScript
# 42          Bash/Shell/PowerShell;C#;HTML/CSS;Java;JavaScr...
# 47          Bash/Shell/PowerShell;C#;Java;JavaScript;Pytho...
# 69                                            HTML/CSS;Python
# ...                                                       ...
# 62863       Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# 62886                       C#;HTML/CSS;JavaScript;TypeScript
# 62904       Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 63288               HTML/CSS;JavaScript;Python;SQL;TypeScript
# 64938       Assembly;C;C++;HTML/CSS;Java;JavaScript;PHP;Py...
#
#                         MiscTechDesireNextYear  \
# Respondent
# 10                           Pandas;TensorFlow
# 33               Node.js;React Native;Unity 3D
# 42                          .NET Core;Teraform
# 47                                      Pandas
# 69                     Keras;Pandas;TensorFlow
# ...                                        ...
# 62863                                  Node.js
# 62886                        .NET Core;Node.js
# 62904                          Flutter;Node.js
# 63288                           Node.js;Pandas
# 64938       Node.js;Pandas;TensorFlow;Unity 3D
#
#                          MiscTechWorkedWith  \
# Respondent
# 10                                   Pandas
# 33                     Node.js;React Native
# 42          .NET;.NET Core;Node.js;Teraform
# 47                           .NET;.NET Core
# 69                  Keras;Pandas;TensorFlow
# ...                                     ...
# 62863       Keras;Node.js;Pandas;TensorFlow
# 62886                        .NET;.NET Core
# 62904                          .NET;Node.js
# 63288                        Node.js;Pandas
# 64938                                Pandas
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 10                                     Github;Microsoft Teams
# 33          Github;Slack;Google Suite (Docs, Meet, etc);St...
# 42                                     Confluence;Jira;Gitlab
# 47                                              Github;Gitlab
# 69                Github;Slack;Google Suite (Docs, Meet, etc)
# ...                                                       ...
# 62863                            Confluence;Jira;Github;Slack
# 62886       Github;Slack;Microsoft Azure;Stack Overflow fo...
# 62904                                            Github;Slack
# 63288                                            Github;Slack
# 64938                     Confluence;Jira;Github;Gitlab;Slack
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 10                                     Github;Microsoft Teams        No
# 33          Confluence;Jira;Github;Gitlab;Slack;Google Sui...       Yes
# 42          Confluence;Jira;Github;Gitlab;Slack;Trello;Goo...       Yes
# 47          Confluence;Jira;Github;Gitlab;Microsoft Azure;...       Yes
# 69          Confluence;Jira;Github;Slack;Google Suite (Doc...       Yes
# ...                                                       ...       ...
# 62863              Confluence;Jira;Github;Gitlab;Slack;Trello       Yes
# 62886                                   Slack;Microsoft Azure        No
# 62904            Confluence;Jira;Github;Slack;Microsoft Teams       Yes
# 63288                                            Github;Slack       Yes
# 64938              Confluence;Jira;Github;Gitlab;Slack;Trello       Yes
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 10                      Neutral                    Fairly important
# 33                      Neutral                  Somewhat important
# 42           Somewhat important  Not at all important/not necessary
# 47                      Neutral  Not at all important/not necessary
# 69          Extremely important                      Very important
# ...                         ...                                 ...
# 62863       Extremely important                    Fairly important
# 62886        Somewhat important                      Very important
# 62904        Somewhat important                      Very important
# 63288        Somewhat important                      Very important
# 64938        Somewhat important                    Fairly important
#
#                                                    NEWJobHunt  \
# Respondent
# 10          Curious about other opportunities;Better compe...
# 33          Just because;Curious about other opportunities...
# 42          Curious about other opportunities;Better compe...
# 47          Just because;Having a bad day (or week or mont...
# 69          Curious about other opportunities;Better compe...
# ...                                                       ...
# 62863       Having a bad day (or week or month) at work;Tr...
# 62886       Curious about other opportunities;Better compe...
# 62904                       Curious about other opportunities
# 63288       Curious about other opportunities;Better compe...
# 64938       Curious about other opportunities;Better compe...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 10          Company reviews from third party sites (e.g. G...
# 33          Company reviews from third party sites (e.g. G...
# 42          Read company media, such as employee blogs or ...
# 47          Read company media, such as employee blogs or ...
# 69          Read company media, such as employee blogs or ...
# ...                                                       ...
# 62863       Company reviews from third party sites (e.g. G...
# 62886       Read company media, such as employee blogs or ...
# 62904       Company reviews from third party sites (e.g. G...
# 63288       Read company media, such as employee blogs or ...
# 64938       Read company media, such as employee blogs or ...
#
#                         NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 10              Every few months         Yes  Onboarding? What onboarding?
# 33                   Once a year          No                            No
# 42          Once every few years         Yes                           Yes
# 47                   Once a year          No  Onboarding? What onboarding?
# 69                   Once a year          No                            No
# ...                          ...         ...                           ...
# 62863           Every few months    Not sure                            No
# 62886       Once every few years         Yes                           Yes
# 62904           Every few months    Not sure                           Yes
# 63288           Every few months    Not sure  Onboarding? What onboarding?
# 64938                Once a year    Not sure                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 10                    No                   Often: 1-2 days per week or more
# 33                    No  Sometimes: 1-2 days per month but less than we...
# 42                   Yes                  Rarely: 1-2 days per year or less
# 47                   Yes  Occasionally: 1-2 days per quarter but less th...
# 69                    No  Sometimes: 1-2 days per month but less than we...
# ...                  ...                                                ...
# 62863                 No  Occasionally: 1-2 days per quarter but less th...
# 62886                 No  Occasionally: 1-2 days per quarter but less th...
# 62904                Yes                   Often: 1-2 days per week or more
# 63288                 No                                              Never
# 64938                 No  Occasionally: 1-2 days per quarter but less th...
#
#                                           NEWPurchaseResearch  \
# Respondent
# 10          Start a free trial;Ask developers I know/work ...
# 33          Ask developers I know/work with;Visit develope...
# 42          Start a free trial;Ask developers I know/work ...
# 47          Start a free trial;Ask developers I know/work ...
# 69          Ask developers I know/work with;Visit develope...
# ...                                                       ...
# 62863       Start a free trial;Ask developers I know/work ...
# 62886       Start a free trial;Ask developers I know/work ...
# 62904       Start a free trial;Ask developers I know/work ...
# 63288       Ask developers I know/work with;Visit develope...
# 64938       Start a free trial;Ask developers I know/work ...
#
#                 NEWPurpleLink  \
# Respondent
# 10          Hello, old friend
# 33          Hello, old friend
# 42                     Amused
# 47          Hello, old friend
# 69          Hello, old friend
# ...                       ...
# 62863             Indifferent
# 62886       Hello, old friend
# 62904             Indifferent
# 63288       Hello, old friend
# 64938       Hello, old friend
#
#                                                    NEWSOSites  \
# Respondent
# 10          Stack Overflow (public Q&A for anyone who code...
# 33          Stack Overflow (public Q&A for anyone who code...
# 42          Stack Overflow (public Q&A for anyone who code...
# 47          Stack Overflow (public Q&A for anyone who code...
# 69          Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 62863       Stack Overflow (public Q&A for anyone who code...
# 62886       Stack Overflow (public Q&A for anyone who code...
# 62904       Stack Overflow (public Q&A for anyone who code...
# 63288       Stack Overflow (public Q&A for anyone who code...
# 64938       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 10                                       Visit Stack Overflow      Windows
# 33          Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 42          Visit Stack Overflow;Go for a walk or other ph...      Windows
# 47          Call a coworker or friend;Visit Stack Overflow...  Linux-based
# 69          Call a coworker or friend;Visit Stack Overflow...        MacOS
# ...                                                       ...          ...
# 62863       Play games;Visit Stack Overflow;Go for a walk ...        MacOS
# 62886       Call a coworker or friend;Visit Stack Overflow...      Windows
# 62904       Call a coworker or friend;Visit Stack Overflow...      Windows
# 63288       Visit Stack Overflow;Watch help / tutorial vid...        MacOS
# 64938       Call a coworker or friend;Visit Stack Overflow...        MacOS
#
#                              OrgSize  \
# Respondent
# 10                  2 to 9 employees
# 33              500 to 999 employees
# 42          1,000 to 4,999 employees
# 47                10 to 19 employees
# 69                20 to 99 employees
# ...                              ...
# 62863           100 to 499 employees
# 62886           100 to 499 employees
# 62904       5,000 to 9,999 employees
# 63288             10 to 19 employees
# 64938           100 to 499 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 10                         Android;Linux;Raspberry Pi;Windows
# 33          Docker;Google Cloud Platform;iOS;Kubernetes;MacOS
# 42                 Android;AWS;Docker;Kubernetes;Raspberry Pi
# 47                          Arduino;Docker;Linux;Raspberry Pi
# 69                                           Kubernetes;Linux
# ...                                                       ...
# 62863                      Docker;Slack Apps and Integrations
# 62886                          Docker;Microsoft Azure;Windows
# 62904       AWS;Docker;Heroku;Kubernetes;Linux;MacOS;Raspb...
# 63288                                              Kubernetes
# 64938                                            Docker;Linux
#
#                                            PlatformWorkedWith  \
# Respondent
# 10                         Android;Linux;Raspberry Pi;Windows
# 33          AWS;Docker;Google Cloud Platform;Heroku;iOS;Ku...
# 42          AWS;Docker;Linux;MacOS;Raspberry Pi;Slack Apps...
# 47             Arduino;AWS;Linux;Microsoft Azure;Raspberry Pi
# 69                                      Linux;Microsoft Azure
# ...                                                       ...
# 62863           AWS;Docker;Heroku;Slack Apps and Integrations
# 62886                                 Microsoft Azure;Windows
# 62904       Android;AWS;Docker;Linux;MacOS;Microsoft Azure...
# 63288                                              Kubernetes
# 64938                                            Docker;Linux
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 10          I have a great deal of influence  Straight / Heterosexual
# 33                     I have some influence  Straight / Heterosexual
# 42                     I have some influence  Straight / Heterosexual
# 47                     I have some influence  Straight / Heterosexual
# 69                     I have some influence                 Bisexual
# ...                                      ...                      ...
# 62863                  I have some influence  Straight / Heterosexual
# 62886                  I have some influence  Straight / Heterosexual
# 62904                  I have some influence  Straight / Heterosexual
# 63288                  I have some influence  Straight / Heterosexual
# 64938                  I have some influence  Straight / Heterosexual
#
#            SOAccount           SOComm  \
# Respondent
# 10               Yes  Yes, definitely
# 33               Yes          Neutral
# 42               Yes   No, not really
# 47               Yes  Yes, definitely
# 69               Yes    Yes, somewhat
# ...              ...              ...
# 62863            Yes   No, not really
# 62886            Yes   No, not really
# 62904            Yes  Yes, definitely
# 63288            Yes   No, not really
# 64938            Yes   No, not really
#
#                                                    SOPartFreq  \
# Respondent
# 10                                     Multiple times per day
# 33                        Less than once per month or monthly
# 42                        Less than once per month or monthly
# 47                                       A few times per week
# 69                            A few times per month or weekly
# ...                                                       ...
# 62863                     Less than once per month or monthly
# 62886                     Less than once per month or monthly
# 62904                         A few times per month or weekly
# 63288       I have never participated in Q&A on Stack Over...
# 64938       I have never participated in Q&A on Stack Over...
#
#                                 SOVisitFreq                  SurveyEase  \
# Respondent
# 10                   Multiple times per day                        Easy
# 33                    Daily or almost daily  Neither easy nor difficult
# 42          A few times per month or weekly                        Easy
# 47                     A few times per week  Neither easy nor difficult
# 69                     A few times per week                        Easy
# ...                                     ...                         ...
# 62863                  A few times per week                        Easy
# 62886                  A few times per week                        Easy
# 62904                Multiple times per day  Neither easy nor difficult
# 63288                  A few times per week                        Easy
# 64938                 Daily or almost daily                        Easy
#
#                      SurveyLength Trans  \
# Respondent
# 10          Appropriate in length    No
# 33          Appropriate in length    No
# 42          Appropriate in length    No
# 47          Appropriate in length    No
# 69                      Too short    No
# ...                           ...   ...
# 62863       Appropriate in length    No
# 62886       Appropriate in length    No
# 62904                    Too long    No
# 63288       Appropriate in length    No
# 64938       Appropriate in length    No
#
#                                                UndergradMajor  \
# Respondent
# 10                                  Mathematics or statistics
# 33          Computer science, computer engineering, or sof...
# 42          Computer science, computer engineering, or sof...
# 47          A natural science (such as biology, chemistry,...
# 69          Computer science, computer engineering, or sof...
# ...                                                       ...
# 62863       Information systems, information technology, o...
# 62886       Information systems, information technology, o...
# 62904       Computer science, computer engineering, or sof...
# 63288       Computer science, computer engineering, or sof...
# 64938       Computer science, computer engineering, or sof...
#
#                            WebframeDesireNextYear  \
# Respondent
# 10                                   Flask;jQuery
# 33          Express;Gatsby;React.js;Ruby on Rails
# 42                            ASP.NET Core;Spring
# 47                                   Flask;Spring
# 69                                   Django;Flask
# ...                                           ...
# 62863                    Angular;Express;React.js
# 62886                                     Angular
# 62904                            Express;React.js
# 63288                  Angular;Angular.js;Express
# 64938                                Django;Flask
#
#                                     WebframeWorkedWith  \
# Respondent
# 10                                        Flask;jQuery
# 33          Angular;Angular.js;Django;Express;React.js
# 42                       ASP.NET;Flask;React.js;Spring
# 47                                        Flask;Spring
# 69                                        Django;Flask
# ...                                                ...
# 62863                                 Express;React.js
# 62886                  Angular;Angular.js;ASP.NET Core
# 62904                  Express;Laravel;React.js;Vue.js
# 63288                       Angular;Angular.js;Express
# 64938                Django;Flask;jQuery;Ruby on Rails
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 10          Somewhat more welcome now than last year         36.0         8
# 33           Just as welcome now as I felt last year         40.0        20
# 42          Somewhat less welcome now than last year         37.0        16
# 47           Just as welcome now as I felt last year         40.0        43
# 69           Just as welcome now as I felt last year         40.0        13
# ...                                              ...          ...       ...
# 62863        Just as welcome now as I felt last year         40.0        10
# 62886       Somewhat more welcome now than last year         45.0         7
# 62904        Just as welcome now as I felt last year         50.0         9
# 63288        Just as welcome now as I felt last year         40.0        14
# 64938        Just as welcome now as I felt last year         40.0        20
#
#            YearsCodePro
# Respondent
# 10                    4
# 33                   14
# 42                   10
# 47                   28
# 69                    3
# ...                 ...
# 62863                 7
# 62886                 5
# 62904                 7
# 63288                 7
# 64938                12
#
# [4213 rows x 60 columns]

# %%
df.dropna(axis='index', how='any', subset=['Age', 'CurrencySymbol'], inplace=True)
df
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 4           I am a developer by profession      Yes   25         18      NaN
# 8           I am a developer by profession      Yes   36         12   Yearly
# 9           I am a developer by profession       No   30         20      NaN
# 10          I am a developer by profession      Yes   22         14   Yearly
# 11          I am a developer by profession      Yes   23         13   Yearly
# ...                                    ...      ...  ...        ...      ...
# 64516       I am a developer by profession      Yes   29         14  Monthly
# 64810       I am a developer by profession      Yes   32         12   Yearly
# 64938       I am a developer by profession       No   33         13   Yearly
# 65414       I am a developer by profession      Yes   22         17  Monthly
# 65629       I am a developer by profession      Yes   41         15   Yearly
#
#             CompTotal  ConvertedComp         Country          CurrencyDesc  \
# Respondent
# 4                 NaN            NaN         Albania          Albanian lek
# 8            116000.0       116000.0   United States  United States dollar
# 9                 NaN            NaN         Tunisia  United States dollar
# 10            25000.0        32315.0  United Kingdom        Pound sterling
# 11            31000.0        40070.0  United Kingdom        Pound sterling
# ...               ...            ...             ...                   ...
# 64516             NaN            NaN         Austria           Swiss franc
# 64810         74500.0        74500.0   United States  United States dollar
# 64938         55000.0        59454.0          France         European Euro
# 65414         30000.0         9612.0       Mauritius       Mauritian rupee
# 65629           200.0          200.0   United States  United States dollar
#
#            CurrencySymbol                  DatabaseDesireNextYear  \
# Respondent
# 4                     ALL                                     NaN
# 8                     USD                                 MongoDB
# 9                     USD                                     NaN
# 10                    GBP                    Microsoft SQL Server
# 11                    GBP             Firebase;MongoDB;PostgreSQL
# ...                   ...                                     ...
# 64516                 CHF     Microsoft SQL Server;MongoDB;SQLite
# 64810                 USD                      MariaDB;PostgreSQL
# 64938                 EUR  Elasticsearch;MongoDB;PostgreSQL;Redis
# 65414                 MUR                                Firebase
# 65629                 USD                              PostgreSQL
#
#                                            DatabaseWorkedWith  \
# Respondent
# 4                                                         NaN
# 8                                         MariaDB;MySQL;Redis
# 9                                                         NaN
# 10                                       Microsoft SQL Server
# 11                         Firebase;MongoDB;PostgreSQL;SQLite
# ...                                                       ...
# 64516                             Microsoft SQL Server;SQLite
# 64810                      MariaDB;Microsoft SQL Server;MySQL
# 64938       DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;Po...
# 65414                     Firebase;Microsoft SQL Server;MySQL
# 65629                                              PostgreSQL
#
#                                                       DevType  \
# Respondent
# 4                                                         NaN
# 8           Developer, back-end;Developer, desktop or ente...
# 9                                       Developer, full-stack
# 10          Database administrator;Developer, full-stack;D...
# 11          Developer, back-end;Developer, desktop or ente...
# ...                                                       ...
# 64516       Developer, back-end;Developer, desktop or ente...
# 64810       Database administrator;Developer, back-end;Dev...
# 64938                   Developer, back-end;DevOps specialist
# 65414       Academic researcher;Designer;Developer, full-s...
# 65629       Developer, back-end;Developer, front-end;Devel...
#
#                                                       EdLevel  \
# Respondent
# 4             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9                          Professional degree (JD, MD, etc.)
# 10            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 64516            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 64810       Some college/university study without earning ...
# 64938                      Professional degree (JD, MD, etc.)
# 65414         Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 65629       Some college/university study without earning ...
#
#                                                    Employment  \
# Respondent
# 4                                                         NaN
# 8                                          Employed full-time
# 9           Independent contractor, freelancer, or self-em...
# 10                                         Employed full-time
# 11                                         Employed full-time
# ...                                                       ...
# 64516       Independent contractor, freelancer, or self-em...
# 64810                                      Employed full-time
# 64938                                      Employed full-time
# 65414                                      Employed full-time
# 65629                                      Employed full-time
#
#                                Ethnicity Gender  \
# Respondent
# 4           White or of European descent    Man
# 8           White or of European descent    Man
# 9                                    NaN    Man
# 10          White or of European descent    Man
# 11          White or of European descent    Man
# ...                                  ...    ...
# 64516       White or of European descent    Man
# 64810       White or of European descent    Man
# 64938       White or of European descent  Woman
# 65414        Black or of African descent    Man
# 65629                                NaN    Man
#
#                                                    JobFactors  \
# Respondent
# 4           Flex time or a flexible schedule;Office enviro...
# 8           Remote work options;Opportunities for professi...
# 9           Diversity of the company or organization;Remot...
# 10          Flex time or a flexible schedule;How widely us...
# 11          Flex time or a flexible schedule;Languages, fr...
# ...                                                       ...
# 64516       Flex time or a flexible schedule;Financial per...
# 64810       Flex time or a flexible schedule;Languages, fr...
# 64938       Flex time or a flexible schedule;Office enviro...
# 65414       Industry that I’d be working in;Diversity of t...
# 65629       Flex time or a flexible schedule;Languages, fr...
#
#                            JobSat  \
# Respondent
# 4           Slightly dissatisfied
# 8           Slightly dissatisfied
# 9               Very dissatisfied
# 10                 Very satisfied
# 11          Slightly dissatisfied
# ...                           ...
# 64516              Very satisfied
# 64810          Slightly satisfied
# 64938              Very satisfied
# 65414              Very satisfied
# 65629              Very satisfied
#
#                                                       JobSeek  \
# Respondent
# 4           I’m not actively looking, but I am open to new...
# 8           I’m not actively looking, but I am open to new...
# 9           I’m not actively looking, but I am open to new...
# 10          I’m not actively looking, but I am open to new...
# 11                            I am actively looking for a job
# ...                                                       ...
# 64516            I am not interested in new job opportunities
# 64810       I’m not actively looking, but I am open to new...
# 64938            I am not interested in new job opportunities
# 65414            I am not interested in new job opportunities
# 65629       I’m not actively looking, but I am open to new...
#
#                                        LanguageDesireNextYear  \
# Respondent
# 4                                                         NaN
# 8                                                  JavaScript
# 9                                                 Python;Rust
# 10                      HTML/CSS;Java;JavaScript;Python;R;SQL
# 11                             Go;JavaScript;Swift;TypeScript
# ...                                                       ...
# 64516       C#;Go;HTML/CSS;JavaScript;Python;R;Ruby;SQL;Ty...
# 64810       Bash/Shell/PowerShell;Go;JavaScript;Python;Typ...
# 64938                                         Go;Python;R;SQL
# 65414                                              TypeScript
# 65629                                                     NaN
#
#                                            LanguageWorkedWith  \
# Respondent
# 4                                                         NaN
# 8                                                  Python;SQL
# 9                                     HTML/CSS;JavaScript;PHP
# 10                        HTML/CSS;Java;JavaScript;Python;SQL
# 11                                        C#;JavaScript;Swift
# ...                                                       ...
# 64516           C#;HTML/CSS;JavaScript;PHP;SQL;TypeScript;VBA
# 64810       Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 64938       Assembly;C;C++;HTML/CSS;Java;JavaScript;PHP;Py...
# 65414                             HTML/CSS;JavaScript;PHP;SQL
# 65629                                                     NaN
#
#                         MiscTechDesireNextYear  \
# Respondent
# 4                                          NaN
# 8                                     Unity 3D
# 9                                          NaN
# 10                           Pandas;TensorFlow
# 11                        Node.js;React Native
# ...                                        ...
# 64516           .NET;.NET Core;Flutter;Node.js
# 64810                               TensorFlow
# 64938       Node.js;Pandas;TensorFlow;Unity 3D
# 65414             Cordova;Flutter;React Native
# 65629                                      NaN
#
#                         MiscTechWorkedWith  \
# Respondent
# 4                                      NaN
# 8                                  Ansible
# 9                                      NaN
# 10                                  Pandas
# 11                                 Node.js
# ...                                    ...
# 64516       .NET;.NET Core;Flutter;Xamarin
# 64810                    .NET Core;Node.js
# 64938                               Pandas
# 65414                              Cordova
# 65629                                  NaN
#
#                                  NEWCollabToolsDesireNextYear  \
# Respondent
# 4                                                         NaN
# 8                                                         NaN
# 9                                                         NaN
# 10                                     Github;Microsoft Teams
# 11           Jira;Github;Slack;Google Suite (Docs, Meet, etc)
# ...                                                       ...
# 64516       Jira;Github;Microsoft Teams;Microsoft Azure;Go...
# 64810             Github;Slack;Google Suite (Docs, Meet, etc)
# 64938                     Confluence;Jira;Github;Gitlab;Slack
# 65414                                                     NaN
# 65629                                                  Gitlab
#
#                                      NEWCollabToolsWorkedWith NEWDevOps  \
# Respondent
# 4                                                         NaN        No
# 8           Confluence;Jira;Github;Slack;Microsoft Teams;G...       Yes
# 9           Github;Slack;Trello;Google Suite (Docs, Meet, ...       NaN
# 10                                     Github;Microsoft Teams        No
# 11          Confluence;Jira;Github;Slack;Microsoft Teams;M...        No
# ...                                                       ...       ...
# 64516       Confluence;Jira;Github;Slack;Microsoft Teams;M...       Yes
# 64810       Confluence;Github;Slack;Microsoft Teams;Micros...        No
# 64938              Confluence;Jira;Github;Gitlab;Slack;Trello       Yes
# 65414                                            Github;Slack       Yes
# 65629                            Confluence;Jira;Github;Slack       Yes
#
#                   NEWDevOpsImpt                           NEWEdImpt  \
# Respondent
# 4                           NaN  Not at all important/not necessary
# 8           Extremely important  Not at all important/not necessary
# 9                           NaN                      Very important
# 10                      Neutral                    Fairly important
# 11          Extremely important                      Very important
# ...                         ...                                 ...
# 64516       Extremely important                Critically important
# 64810        Somewhat important  Not at all important/not necessary
# 64938        Somewhat important                    Fairly important
# 65414       Extremely important                    Fairly important
# 65629        Somewhat important  Not at all important/not necessary
#
#                                                    NEWJobHunt  \
# Respondent
# 4           Curious about other opportunities;Wanting to w...
# 8           Curious about other opportunities;Better compe...
# 9           Curious about other opportunities;Growth or le...
# 10          Curious about other opportunities;Better compe...
# 11          Curious about other opportunities;Better compe...
# ...                                                       ...
# 64516       Having a bad day (or week or month) at work;Cu...
# 64810       Having a bad day (or week or month) at work;Cu...
# 64938       Curious about other opportunities;Better compe...
# 65414       Wanting to work with new technologies;Growth o...
# 65629       Curious about other opportunities;Better compe...
#
#                                            NEWJobHuntResearch  \
# Respondent
# 4                                                         NaN
# 8           Read company media, such as employee blogs or ...
# 9                                                         NaN
# 10          Company reviews from third party sites (e.g. G...
# 11          Read company media, such as employee blogs or ...
# ...                                                       ...
# 64516       Read company media, such as employee blogs or ...
# 64810       Read company media, such as employee blogs or ...
# 64938       Read company media, such as employee blogs or ...
# 65414       Read company media, such as employee blogs or ...
# 65629       Read company media, such as employee blogs or ...
#
#                     NEWLearn NEWOffTopic                NEWOnboardGood  \
# Respondent
# 4                Once a year    Not sure                           Yes
# 8                Once a year    Not sure                           Yes
# 9                Once a year          No                           Yes
# 10          Every few months         Yes  Onboarding? What onboarding?
# 11          Every few months          No                           Yes
# ...                      ...         ...                           ...
# 64516            Once a year          No                           Yes
# 64810            Once a year    Not sure                            No
# 64938            Once a year    Not sure                           Yes
# 65414                    NaN          No                           Yes
# 65629       Every few months    Not sure                           Yes
#
#            NEWOtherComms                                        NEWOvertime  \
# Respondent
# 4                    Yes  Occasionally: 1-2 days per quarter but less th...
# 8                     No  Occasionally: 1-2 days per quarter but less th...
# 9                     No  Occasionally: 1-2 days per quarter but less th...
# 10                    No                   Often: 1-2 days per week or more
# 11                    No                  Rarely: 1-2 days per year or less
# ...                  ...                                                ...
# 64516                Yes  Sometimes: 1-2 days per month but less than we...
# 64810                 No  Occasionally: 1-2 days per quarter but less th...
# 64938                 No  Occasionally: 1-2 days per quarter but less th...
# 65414                Yes                   Often: 1-2 days per week or more
# 65629                Yes                                              Never
#
#                                           NEWPurchaseResearch  \
# Respondent
# 4                                                         NaN
# 8           Start a free trial;Ask developers I know/work ...
# 9                                          Start a free trial
# 10          Start a free trial;Ask developers I know/work ...
# 11                                                        NaN
# ...                                                       ...
# 64516       Ask developers I know/work with;Visit develope...
# 64810       Start a free trial;Ask developers I know/work ...
# 64938       Start a free trial;Ask developers I know/work ...
# 65414                                                     NaN
# 65629                         Ask developers I know/work with
#
#                 NEWPurpleLink  \
# Respondent
# 4                         NaN
# 8           Hello, old friend
# 9           Hello, old friend
# 10          Hello, old friend
# 11                    Annoyed
# ...                       ...
# 64516       Hello, old friend
# 64810                  Amused
# 64938       Hello, old friend
# 65414             Indifferent
# 65629             Indifferent
#
#                                                    NEWSOSites  \
# Respondent
# 4           Stack Overflow (public Q&A for anyone who code...
# 8           Stack Overflow (public Q&A for anyone who code...
# 9           Stack Overflow (public Q&A for anyone who code...
# 10          Stack Overflow (public Q&A for anyone who code...
# 11          Stack Overflow (public Q&A for anyone who code...
# ...                                                       ...
# 64516       Stack Overflow (public Q&A for anyone who code...
# 64810       Stack Overflow (public Q&A for anyone who code...
# 64938       Stack Overflow (public Q&A for anyone who code...
# 65414       Stack Overflow (public Q&A for anyone who code...
# 65629       Stack Overflow (public Q&A for anyone who code...
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 4                                                         NaN  Linux-based
# 8           Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 9                                                    Meditate      Windows
# 10                                       Visit Stack Overflow      Windows
# 11          Play games;Call a coworker or friend;Visit Sta...      Windows
# ...                                                       ...          ...
# 64516       Call a coworker or friend;Visit Stack Overflow...      Windows
# 64810       Play games;Call a coworker or friend;Visit Sta...  Linux-based
# 64938       Call a coworker or friend;Visit Stack Overflow...        MacOS
# 65414       Call a coworker or friend;Visit Stack Overflow...        MacOS
# 65629                Go for a walk or other physical activity        MacOS
#
#                                                       OrgSize  \
# Respondent
# 4                                          20 to 99 employees
# 8                                          20 to 99 employees
# 9           Just me - I am a freelancer, sole proprietor, ...
# 10                                           2 to 9 employees
# 11                                   10,000 or more employees
# ...                                                       ...
# 64516                                        2 to 9 employees
# 64810                                      10 to 19 employees
# 64938                                    100 to 499 employees
# 65414                                      10 to 19 employees
# 65629                                    100 to 499 employees
#
#                                        PlatformDesireNextYear  \
# Respondent
# 4                                                         NaN
# 8                             iOS;Slack Apps and Integrations
# 9                                                         NaN
# 10                         Android;Linux;Raspberry Pi;Windows
# 11                                       AWS;Docker;iOS;MacOS
# ...                                                       ...
# 64516       AWS;Docker;MacOS;Microsoft Azure;Raspberry Pi;...
# 64810                                      Linux;Raspberry Pi
# 64938                                            Docker;Linux
# 65414                                             Android;iOS
# 65629                                      Docker;Linux;MacOS
#
#                                            PlatformWorkedWith  \
# Respondent
# 4                                                         NaN
# 8                                                      Docker
# 9                                                   WordPress
# 10                         Android;Linux;Raspberry Pi;Windows
# 11                                             AWS;Heroku;iOS
# ...                                                       ...
# 64516       MacOS;Microsoft Azure;Slack Apps and Integrati...
# 64810                                             Linux;MacOS
# 64938                                            Docker;Linux
# 65414                           Linux;MacOS;Windows;WordPress
# 65629                                      Docker;Linux;MacOS
#
#                                 PurchaseWhat                Sexuality  \
# Respondent
# 4           I have a great deal of influence  Straight / Heterosexual
# 8                      I have some influence  Straight / Heterosexual
# 9                                        NaN  Straight / Heterosexual
# 10          I have a great deal of influence  Straight / Heterosexual
# 11             I have little or no influence  Straight / Heterosexual
# ...                                      ...                      ...
# 64516                                    NaN  Straight / Heterosexual
# 64810                  I have some influence                      NaN
# 64938                  I have some influence  Straight / Heterosexual
# 65414          I have little or no influence  Straight / Heterosexual
# 65629                  I have some influence  Straight / Heterosexual
#
#            SOAccount           SOComm  \
# Respondent
# 4                Yes  Yes, definitely
# 8                Yes   No, not really
# 9                Yes  Yes, definitely
# 10               Yes  Yes, definitely
# 11               Yes    Yes, somewhat
# ...              ...              ...
# 64516            Yes    Yes, somewhat
# 64810            Yes    Yes, somewhat
# 64938            Yes   No, not really
# 65414            Yes    Yes, somewhat
# 65629            Yes    Yes, somewhat
#
#                                                    SOPartFreq  \
# Respondent
# 4                             A few times per month or weekly
# 8                         Less than once per month or monthly
# 9                                      Multiple times per day
# 10                                     Multiple times per day
# 11          I have never participated in Q&A on Stack Over...
# ...                                                       ...
# 64516                                    A few times per week
# 64810                     Less than once per month or monthly
# 64938       I have never participated in Q&A on Stack Over...
# 65414       I have never participated in Q&A on Stack Over...
# 65629                     Less than once per month or monthly
#
#                                     SOVisitFreq                  SurveyEase  \
# Respondent
# 4                        Multiple times per day                         NaN
# 8                        Multiple times per day                        Easy
# 9                        Multiple times per day  Neither easy nor difficult
# 10                       Multiple times per day                        Easy
# 11                       Multiple times per day                        Easy
# ...                                         ...                         ...
# 64516                    Multiple times per day                         NaN
# 64810                     Daily or almost daily                        Easy
# 64938                     Daily or almost daily                        Easy
# 65414                    Multiple times per day                   Difficult
# 65629       Less than once per month or monthly                         NaN
#
#                      SurveyLength Trans  \
# Respondent
# 4                             NaN    No
# 8           Appropriate in length    No
# 9           Appropriate in length    No
# 10          Appropriate in length    No
# 11          Appropriate in length    No
# ...                           ...   ...
# 64516                         NaN    No
# 64810       Appropriate in length    No
# 64938       Appropriate in length    No
# 65414                    Too long    No
# 65629                         NaN    No
#
#                                                UndergradMajor  \
# Respondent
# 4           Computer science, computer engineering, or sof...
# 8           Computer science, computer engineering, or sof...
# 9           Computer science, computer engineering, or sof...
# 10                                  Mathematics or statistics
# 11          Computer science, computer engineering, or sof...
# ...                                                       ...
# 64516       Computer science, computer engineering, or sof...
# 64810       Computer science, computer engineering, or sof...
# 64938       Computer science, computer engineering, or sof...
# 65414       Computer science, computer engineering, or sof...
# 65629       Computer science, computer engineering, or sof...
#
#                                        WebframeDesireNextYear  \
# Respondent
# 4                                                         NaN
# 8                                      Django;React.js;Vue.js
# 9                                                  Angular.js
# 10                                               Flask;jQuery
# 11                                    Angular;Django;React.js
# ...                                                       ...
# 64516       Angular;Angular.js;ASP.NET;ASP.NET Core;Expres...
# 64810                     Django;Flask;jQuery;React.js;Vue.js
# 64938                                            Django;Flask
# 65414                                          Angular;Django
# 65629                                                React.js
#
#                                         WebframeWorkedWith  \
# Respondent
# 4                                                      NaN
# 8                                                    Flask
# 9                                                   jQuery
# 10                                            Flask;jQuery
# 11                      Angular;Angular.js;Django;React.js
# ...                                                    ...
# 64516       Angular;Angular.js;ASP.NET;ASP.NET Core;jQuery
# 64810                   Angular;ASP.NET Core;Django;jQuery
# 64938                    Django;Flask;jQuery;Ruby on Rails
# 65414                       Gatsby;jQuery;Laravel;React.js
# 65629                                             React.js
#
#                                        WelcomeChange  WorkWeekHrs YearsCode  \
# Respondent
# 4           Somewhat less welcome now than last year         40.0         7
# 8            Just as welcome now as I felt last year         39.0        17
# 9            Just as welcome now as I felt last year         50.0         6
# 10          Somewhat more welcome now than last year         36.0         8
# 11           Just as welcome now as I felt last year         40.0        10
# ...                                              ...          ...       ...
# 64516        Just as welcome now as I felt last year          NaN        12
# 64810        Just as welcome now as I felt last year         35.0        19
# 64938        Just as welcome now as I felt last year         40.0        20
# 65414        Just as welcome now as I felt last year         40.0         5
# 65629        Just as welcome now as I felt last year          NaN        25
#
#            YearsCodePro
# Respondent
# 4                     4
# 8                    13
# 9                     4
# 10                    4
# 11                    2
# ...                 ...
# 64516                 7
# 64810                 7
# 64938                12
# 65414                 3
# 65629                20
#
# [36441 rows x 60 columns]

# %%
df[['Age', 'CurrencySymbol']].head(10)
# Out:
#             Age CurrencySymbol
# Respondent
# 4            25            ALL
# 8            36            USD
# 9            30            USD
# 10           22            GBP
# 11           23            GBP
# 12           49            EUR
# 13           53            EUR
# 14           27            USD
# 16           45            GBP
# 17           25            USD

# %%
df.isna()             # df.fillna("Missing")
# Out:
#             MainBranch  Hobbyist    Age  Age1stCode  CompFreq  CompTotal  \
# Respondent
# 4                False     False  False       False      True       True
# 8                False     False  False       False     False      False
# 9                False     False  False       False      True       True
# 10               False     False  False       False     False      False
# 11               False     False  False       False     False      False
# ...                ...       ...    ...         ...       ...        ...
# 64516            False     False  False       False     False       True
# 64810            False     False  False       False     False      False
# 64938            False     False  False       False     False      False
# 65414            False     False  False       False     False      False
# 65629            False     False  False       False     False      False
#
#             ConvertedComp  Country  CurrencyDesc  CurrencySymbol  \
# Respondent
# 4                    True    False         False           False
# 8                   False    False         False           False
# 9                    True    False         False           False
# 10                  False    False         False           False
# 11                  False    False         False           False
# ...                   ...      ...           ...             ...
# 64516                True    False         False           False
# 64810               False    False         False           False
# 64938               False    False         False           False
# 65414               False    False         False           False
# 65629               False    False         False           False
#
#             DatabaseDesireNextYear  DatabaseWorkedWith  DevType  EdLevel  \
# Respondent
# 4                             True                True     True    False
# 8                            False               False    False    False
# 9                             True                True    False    False
# 10                           False               False    False    False
# 11                           False               False    False    False
# ...                            ...                 ...      ...      ...
# 64516                        False               False    False    False
# 64810                        False               False    False    False
# 64938                        False               False    False    False
# 65414                        False               False    False    False
# 65629                        False               False    False    False
#
#             Employment  Ethnicity  Gender  JobFactors  JobSat  JobSeek  \
# Respondent
# 4                 True      False   False       False   False    False
# 8                False      False   False       False   False    False
# 9                False       True   False       False   False    False
# 10               False      False   False       False   False    False
# 11               False      False   False       False   False    False
# ...                ...        ...     ...         ...     ...      ...
# 64516            False      False   False       False   False    False
# 64810            False      False   False       False   False    False
# 64938            False      False   False       False   False    False
# 65414            False      False   False       False   False    False
# 65629            False       True   False       False   False    False
#
#             LanguageDesireNextYear  LanguageWorkedWith  \
# Respondent
# 4                             True                True
# 8                            False               False
# 9                            False               False
# 10                           False               False
# 11                           False               False
# ...                            ...                 ...
# 64516                        False               False
# 64810                        False               False
# 64938                        False               False
# 65414                        False               False
# 65629                         True                True
#
#             MiscTechDesireNextYear  MiscTechWorkedWith  \
# Respondent
# 4                             True                True
# 8                            False               False
# 9                             True                True
# 10                           False               False
# 11                           False               False
# ...                            ...                 ...
# 64516                        False               False
# 64810                        False               False
# 64938                        False               False
# 65414                        False               False
# 65629                         True                True
#
#             NEWCollabToolsDesireNextYear  NEWCollabToolsWorkedWith  NEWDevOps  \
# Respondent
# 4                                   True                      True      False
# 8                                   True                     False      False
# 9                                   True                     False       True
# 10                                 False                     False      False
# 11                                 False                     False      False
# ...                                  ...                       ...        ...
# 64516                              False                     False      False
# 64810                              False                     False      False
# 64938                              False                     False      False
# 65414                               True                     False      False
# 65629                              False                     False      False
#
#             NEWDevOpsImpt  NEWEdImpt  NEWJobHunt  NEWJobHuntResearch  \
# Respondent
# 4                    True      False       False                True
# 8                   False      False       False               False
# 9                    True      False       False                True
# 10                  False      False       False               False
# 11                  False      False       False               False
# ...                   ...        ...         ...                 ...
# 64516               False      False       False               False
# 64810               False      False       False               False
# 64938               False      False       False               False
# 65414               False      False       False               False
# 65629               False      False       False               False
#
#             NEWLearn  NEWOffTopic  NEWOnboardGood  NEWOtherComms  NEWOvertime  \
# Respondent
# 4              False        False           False          False        False
# 8              False        False           False          False        False
# 9              False        False           False          False        False
# 10             False        False           False          False        False
# 11             False        False           False          False        False
# ...              ...          ...             ...            ...          ...
# 64516          False        False           False          False        False
# 64810          False        False           False          False        False
# 64938          False        False           False          False        False
# 65414           True        False           False          False        False
# 65629          False        False           False          False        False
#
#             NEWPurchaseResearch  NEWPurpleLink  NEWSOSites  NEWStuck  OpSys  \
# Respondent
# 4                          True           True       False      True  False
# 8                         False          False       False     False  False
# 9                         False          False       False     False  False
# 10                        False          False       False     False  False
# 11                         True          False       False     False  False
# ...                         ...            ...         ...       ...    ...
# 64516                     False          False       False     False  False
# 64810                     False          False       False     False  False
# 64938                     False          False       False     False  False
# 65414                      True          False       False     False  False
# 65629                     False          False       False     False  False
#
#             OrgSize  PlatformDesireNextYear  PlatformWorkedWith  PurchaseWhat  \
# Respondent
# 4             False                    True                True         False
# 8             False                   False               False         False
# 9             False                    True               False          True
# 10            False                   False               False         False
# 11            False                   False               False         False
# ...             ...                     ...                 ...           ...
# 64516         False                   False               False          True
# 64810         False                   False               False         False
# 64938         False                   False               False         False
# 65414         False                   False               False         False
# 65629         False                   False               False         False
#
#             Sexuality  SOAccount  SOComm  SOPartFreq  SOVisitFreq  SurveyEase  \
# Respondent
# 4               False      False   False       False        False        True
# 8               False      False   False       False        False       False
# 9               False      False   False       False        False       False
# 10              False      False   False       False        False       False
# 11              False      False   False       False        False       False
# ...               ...        ...     ...         ...          ...         ...
# 64516           False      False   False       False        False        True
# 64810            True      False   False       False        False       False
# 64938           False      False   False       False        False       False
# 65414           False      False   False       False        False       False
# 65629           False      False   False       False        False        True
#
#             SurveyLength  Trans  UndergradMajor  WebframeDesireNextYear  \
# Respondent
# 4                   True  False           False                    True
# 8                  False  False           False                   False
# 9                  False  False           False                   False
# 10                 False  False           False                   False
# 11                 False  False           False                   False
# ...                  ...    ...             ...                     ...
# 64516               True  False           False                   False
# 64810              False  False           False                   False
# 64938              False  False           False                   False
# 65414              False  False           False                   False
# 65629               True  False           False                   False
#
#             WebframeWorkedWith  WelcomeChange  WorkWeekHrs  YearsCode  \
# Respondent
# 4                         True          False        False      False
# 8                        False          False        False      False
# 9                        False          False        False      False
# 10                       False          False        False      False
# 11                       False          False        False      False
# ...                        ...            ...          ...        ...
# 64516                    False          False         True      False
# 64810                    False          False        False      False
# 64938                    False          False        False      False
# 65414                    False          False        False      False
# 65629                    False          False         True      False
#
#             YearsCodePro
# Respondent
# 4                  False
# 8                  False
# 9                  False
# 10                 False
# 11                 False
# ...                  ...
# 64516              False
# 64810              False
# 64938              False
# 65414              False
# 65629              False
#
# [36441 rows x 60 columns]

# %%
df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                               int32
# Age1stCode                       object
# CompFreq                         object
# CompTotal                       float64
# ConvertedComp                   float64
# Country                          object
# CurrencyDesc                     object
# CurrencySymbol                   object
# DatabaseDesireNextYear           object
# DatabaseWorkedWith               object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# JobSeek                          object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# MiscTechWorkedWith               object
# NEWCollabToolsDesireNextYear     object
# NEWCollabToolsWorkedWith         object
# NEWDevOps                        object
# NEWDevOpsImpt                    object
# NEWEdImpt                        object
# NEWJobHunt                       object
# NEWJobHuntResearch               object
# NEWLearn                         object
# NEWOffTopic                      object
# NEWOnboardGood                   object
# NEWOtherComms                    object
# NEWOvertime                      object
# NEWPurchaseResearch              object
# NEWPurpleLink                    object
# NEWSOSites                       object
# NEWStuck                         object
# OpSys                            object
# OrgSize                          object
# PlatformDesireNextYear           object
# PlatformWorkedWith               object
# PurchaseWhat                     object
# Sexuality                        object
# SOAccount                        object
# SOComm                           object
# SOPartFreq                       object
# SOVisitFreq                      object
# SurveyEase                       object
# SurveyLength                     object
# Trans                            object
# UndergradMajor                   object
# WebframeDesireNextYear           object
# WebframeWorkedWith               object
# WelcomeChange                    object
# WorkWeekHrs                     float64
# YearsCode                        object
# YearsCodePro                     object
# dtype: object

# %%
df['Age'] = df['Age'].astype(int)

# %%
df['Age'].mean()
# Out:
# 32.17266266019045

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-14e5d2cf29c5> in <module>
# ----> 1 df['YearsCode'] = df['YearsCode'].astype(float)
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     895     if copy or is_object_dtype(arr) or is_object_dtype(dtype):
#     896         # Explicit copy, or required since NumPy can't view from / to object.
# --> 897         return arr.astype(dtype, copy=True)
#     898
#     899     return arr.view(dtype)
#
# ValueError: could not convert string to float: 'More than 50 years'

# %%
df['YearsCode'].unique()
# Out:
# array(['7', '17', '6', '8', '10', '35', '5', '37', '19', '9', '22', '30',
#        '20', '4', '2', '16', '43', '11', '38', '33', '24', '21', '13',
#        '3', '15', '27', '25', '12', '46', '14', '28', '18', '32', '44',
#        '40', '26', '36', '42', '31', '34', '29', '1', '23', nan, '45',
#        '41', 'More than 50 years', '39', '47', 'Less than 1 year', '50',
#        '48', '49'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].mean()
# Out:
# 14.331377410468319

# %%
df['YearsCode'].median()
# Out:
# 12.0
